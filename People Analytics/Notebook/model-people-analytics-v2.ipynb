# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import pandas_profiling

# library untuk eksplorasi data
import matplotlib.pyplot as plt
import seaborn as sns

# library untuk membagi data
from sklearn.model_selection import train_test_split

# library untuk evaluasi hasil prediksi
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score

# library untuk bebrapa model
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier

from sklearn.feature_selection import SelectFromModel

# library untuk tunning parameter
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# library untuk menggabungkan beberapa algoritme
from imblearn.pipeline import Pipeline
# library untuk menyeimbangkan data
from imblearn.over_sampling import SMOTE

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder, StandardScaler, KBinsDiscretizer
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.compose import ColumnTransformer
# import category_encoders as ce

from sklearn.calibration import CalibratedClassifierCV
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\dask\dataframe\utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
pd.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (11153, 22)
# (6000, 21)

# %%
df_train.head(15)
# Out:
#    job_level  job_duration_in_current_job_level person_level  \
# 0       JG04                           1.352775         PG03
# 1       JG04                           1.292285         PG03
# 2       JG05                           2.565151         PG06
# 3       JG05                           2.828427         PG06
# 4       JG05                           2.828427         PG06
# 5       JG05                           2.828427         PG06
# 6       JG05                           2.828427         PG06
# 7       JG05                           2.828427         PG06
# 8       JG04                           1.118034         PG03
# 9       JG04                           1.118034         PG03
# 10      JG05                           2.828427         PG06
# 11      JG04                           1.322876         PG03
# 12      JG04                           1.081665         PG03
# 13      JG04                           1.385641         PG03
# 14      JG04                           1.385641         PG03
#
#     job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                               1.352775                        1.732051
# 1                               1.292285                        1.039230
# 2                               2.308679                        1.780449
# 3                               1.000000                        1.385641
# 4                               2.828427                        0.707107
# 5                               2.121320                        1.118034
# 6                               2.345208                        2.102380
# 7                               2.236068                        1.581139
# 8                               1.118034                        0.412311
# 9                               1.118034                        0.412311
# 10                              2.236068                        0.707107
# 11                              1.322876                        0.707107
# 12                              1.081665                        1.224745
# 13                              1.385641                        0.648074
# 14                              1.385641                        0.707107
#
#    Employee_type  gender   age marital_status_maried(Y/N)  \
# 0      RM_type_A       2  1985                          Y
# 1      RM_type_A       2  1989                          Y
# 2      RM_type_C       1  1970                          Y
# 3      RM_type_A       2  1967                          Y
# 4      RM_type_A       2  1965                          Y
# 5      RM_type_A       1  1971                          Y
# 6      RM_type_A       1  1969                          Y
# 7      RM_type_C       2  1968                          Y
# 8      RM_type_B       1  1989                          Y
# 9      RM_type_B       2  1991                          N
# 10     RM_type_A       2  1966                          Y
# 11     RM_type_B       2  1989                          Y
# 12     RM_type_B       1  1993                          N
# 13     RM_type_B       2  1980                          N
# 14     RM_type_B       2  1974                          Y
#
#     number_of_dependences Education_level   GPA  year_graduated  \
# 0                       1         level_0  2.86            2011
# 1                       0         level_1  7.28            2007
# 2                       1         level_1  0.00            1989
# 3                       2         level_1  0.00            1987
# 4                       3         level_1  7.20            1985
# 5                       3         level_1  0.00            1990
# 6                       2         level_1  0.00            1988
# 7                       2         level_1  0.00            1987
# 8                       0         level_1  3.01            2007
# 9                       0         level_1  4.19            2009
# 10                      2         level_1  0.00            1985
# 11                      0         level_1  2.96            2007
# 12                      0         level_1  8.30            2011
# 13                      0         level_1  0.00            1999
# 14                      0         level_1  0.00            1992
#
#     job_duration_from_training  branch_rotation  job_rotation  \
# 0                            4                2             3
# 1                            4                4             3
# 2                           28               10             9
# 3                           29               11             6
# 4                           30                9             8
# 5                           28                7             9
# 6                           29                8             6
# 7                           29                6             8
# 8                            3                2             2
# 9                            3                2             2
# 10                          29                8             9
# 11                           3                2             2
# 12                           3                2             2
# 13                           5                6             3
# 14                           6                4             6
#
#     assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                         2             3            0               46.37
# 1                         0             0            1               47.68
# 2                         6             2            1               40.73
# 3                         0             4           10               47.42
# 4                         2             3            0               47.18
# 5                         4             0            0               48.46
# 6                         2             8            0               60.38
# 7                         1             3            4               14.71
# 8                         0             9            0               26.76
# 9                         0             3            0               41.45
# 10                        0            11            3               46.30
# 11                        0             8            0               49.15
# 12                        0             3            0               44.93
# 13                        0             5            5               73.56
# 14                        0             3            6               41.80
#
#     Achievement_above_100%_during3quartal  Best Performance
# 0                                     0.0                 0
# 1                                     0.0                 0
# 2                                     0.0                 0
# 3                                     0.0                 1
# 4                                     0.0                 0
# 5                                     0.0                 0
# 6                                     0.0                 0
# 7                                     0.0                 0
# 8                                     0.0                 0
# 9                                     0.0                 1
# 10                                    0.0                 0
# 11                                    0.0                 0
# 12                                    0.0                 0
# 13                                    1.0                 0
# 14                                    0.0                 0

# %%
df_test.head()
# Out:
#   job_level  job_duration_in_current_job_level person_level  \
# 0      JG04                           1.256981         PG03
# 1      JG04                           1.224745         PG03
# 2      JG04                           0.500000         PG03
# 3      JG04                           1.256981         PG03
# 4      JG04                           1.352775         PG03
#
#    job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                              1.256981                        0.707107
# 1                              1.224745                        1.256981
# 2                              0.500000                        1.081665
# 3                              1.256981                        1.802776
# 4                              1.352775                        1.224745
#
#   Employee_type  gender   age marital_status_maried(Y/N)  \
# 0     RM_type_A       1  1988                          N
# 1     RM_type_B       2  1991                          N
# 2     RM_type_A       2  1989                          Y
# 3     RM_type_A       2  1990                          Y
# 4     RM_type_B       1  1985                          Y
#
#    number_of_dependences Education_level   GPA  year_graduated  \
# 0                      0         level_3  3.08            2009
# 1                      0         level_4  3.31            2014
# 2                      1         level_4  3.44            2011
# 3                      1         level_4  0.00            2014
# 4                      0         level_4  3.34            2007
#
#    job_duration_from_training  branch_rotation  job_rotation  \
# 0                           6                4             2
# 1                           2                2             2
# 2                           4                2             2
# 3                           3                1             3
# 4                           5                3             2
#
#    assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                        6             3            7               84.02
# 1                        0             1            0               63.74
# 2                        0             2            1               88.19
# 3                        0             3            0               25.94
# 4                        0             3            0               82.32
#
#    Achievement_above_100%_during3quartal
# 0                                    0.0
# 1                                    0.0
# 2                                    1.0
# 3                                    0.0
# 4                                    0.0

# %% [markdown]
# # EDA

# %%
def understand(df):
    
    print("Data Dimension: \n",df.shape,"\n")
    df_summary = pd.DataFrame((df.isnull().sum()/df.shape[0])*100,columns=['missing'])
    df_summary.sort_values(by='missing',ascending=False,inplace=True)
    df_summary['missing num']=df.isnull().sum()
    df_summary['data types']=df.dtypes
    
    return df_summary[df_summary['missing']>0]

# %%
understand(df_train)
# Out:
# Data Dimension:
#  (11153, 22)
#                                         missing  missing num data types
# Achievement_above_100%_during3quartal  0.008966            1    float64
# Last_achievement_%                     0.008966            1    float64

# %%
understand(df_train).index
# Out:
# Data Dimension:
#  (11153, 22)
# Index(['Achievement_above_100%_during3quartal', 'Last_achievement_%'], dtype='object')

# %%
understand(df_test)
# Out:
# Data Dimension:
#  (6000, 21)
# Empty DataFrame
# Columns: [missing, missing num, data types]
# Index: []

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df_train.isnull())

# %%
df_train.dropna()
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 0          JG04                           1.352775         PG03
# 1          JG04                           1.292285         PG03
# 2          JG05                           2.565151         PG06
# 3          JG05                           2.828427         PG06
# 4          JG05                           2.828427         PG06
# ...         ...                                ...          ...
# 11148      JG04                           1.256981         PG03
# 11149      JG04                           1.385641         PG03
# 11150      JG04                           1.256981         PG03
# 11151      JG04                           1.118034         PG03
# 11152      JG04                           2.828427         PG04
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                                  1.352775                        1.732051
# 1                                  1.292285                        1.039230
# 2                                  2.308679                        1.780449
# 3                                  1.000000                        1.385641
# 4                                  2.828427                        0.707107
# ...                                     ...                             ...
# 11148                              1.256981                        1.224745
# 11149                              1.385641                        1.802776
# 11150                              1.256981                        1.385641
# 11151                              1.118034                        0.000000
# 11152                              2.121320                        1.473092
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 0         RM_type_A       2  1985                          Y
# 1         RM_type_A       2  1989                          Y
# 2         RM_type_C       1  1970                          Y
# 3         RM_type_A       2  1967                          Y
# 4         RM_type_A       2  1965                          Y
# ...             ...     ...   ...                        ...
# 11148     RM_type_A       2  1986                          Y
# 11149     RM_type_B       1  1988                          Y
# 11150     RM_type_B       2  1991                          Y
# 11151     RM_type_A       1  1987                          Y
# 11152     RM_type_B       2  1980                          Y
#
#        number_of_dependences Education_level   GPA  year_graduated  \
# 0                          1         level_0  2.86            2011
# 1                          0         level_1  7.28            2007
# 2                          1         level_1  0.00            1989
# 3                          2         level_1  0.00            1987
# 4                          3         level_1  7.20            1985
# ...                      ...             ...   ...             ...
# 11148                      1         level_5  3.33            2016
# 11149                      2         level_5  3.00            2015
# 11150                      0         level_5  3.48            2017
# 11151                      1         level_5  3.53            2012
# 11152                      2         level_5  3.14            2009
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 0                               4                2             3
# 1                               4                4             3
# 2                              28               10             9
# 3                              29               11             6
# 4                              30                9             8
# ...                           ...              ...           ...
# 11148                           4                3             3
# 11149                           3                1             2
# 11150                           2                1             2
# 11151                           5                5             4
# 11152                          14                5             7
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                            2             3            0               46.37
# 1                            0             0            1               47.68
# 2                            6             2            1               40.73
# 3                            0             4           10               47.42
# 4                            2             3            0               47.18
# ...                        ...           ...          ...                 ...
# 11148                        0             4            1               50.87
# 11149                        0             6            0               79.91
# 11150                        0             4            0               78.38
# 11151                        0             4            1               85.94
# 11152                        0             2            0               79.99
#
#        Achievement_above_100%_during3quartal  Best Performance
# 0                                        0.0                 0
# 1                                        0.0                 0
# 2                                        0.0                 0
# 3                                        0.0                 1
# 4                                        0.0                 0
# ...                                      ...               ...
# 11148                                    0.0                 0
# 11149                                    0.0                 0
# 11150                                    0.0                 0
# 11151                                    1.0                 0
# 11152                                    1.0                 0
#
# [11152 rows x 22 columns]

# %% [markdown]
# > ## Best Performance

# %%
df_train['Best Performance'].value_counts()
# Out:
# 0    9516
# 1    1637
# Name: Best Performance, dtype: int64

# %%
df_train.dropna()['Best Performance'].value_counts()
# Out:
# 0    9515
# 1    1637
# Name: Best Performance, dtype: int64

# %%
df_train[df_train['Achievement_above_100%_during3quartal'].isnull()]['Best Performance'].value_counts()
# Out:
# 0    1
# Name: Best Performance, dtype: int64

# %% [markdown]
# > ## Object Var

# %%
object_var = df_train.columns[df_train.dtypes == object]

# %%
for i in object_var:
    print(df_train[i].value_counts().sort_index(),'\n')
# Out:
# JG03       36
# JG04    10413
# JG05      704
# Name: job_level, dtype: int64
#
# PG01      19
# PG02      16
# PG03    9655
# PG04     757
# PG05     308
# PG06     378
# PG07      19
# PG08       1
# Name: person_level, dtype: int64
#
# RM_type_A    7287
# RM_type_B    3380
# RM_type_C     486
# Name: Employee_type, dtype: int64
#
# N    1652
# Y    9501
# Name: marital_status_maried(Y/N), dtype: int64
#
# level_0       1
# level_1     140
# level_2       4
# level_3    1743
# level_4    9222
# level_5      43
# Name: Education_level, dtype: int64

# %%
for i in object_var:
    print(df_test[i].value_counts().sort_index(),'\n')
# Out:
# JG03      11
# JG04    5616
# JG05     372
# JG06       1
# Name: job_level, dtype: int64
#
# PG01       6
# PG02       5
# PG03    5211
# PG04     403
# PG05     159
# PG06     203
# PG07      13
# Name: person_level, dtype: int64
#
# RM_type_A    3875
# RM_type_B    1831
# RM_type_C     294
# Name: Employee_type, dtype: int64
#
# N     890
# Y    5110
# Name: marital_status_maried(Y/N), dtype: int64
#
# level_0       1
# level_1      75
# level_2       2
# level_3     944
# level_4    4950
# level_5      28
# Name: Education_level, dtype: int64

# %% [markdown]
# > ## Year

# %%
df_train['year_graduated'].value_counts()
# Out:
# 2011    1693
# 2010    1531
# 2012    1339
# 2009    1204
# 2008    1069
# 2013     875
# 2007     670
# 2014     616
# 2006     421
# 2005     295
# 2004     278
# 2003     255
# 2002     172
# 2015     163
# 2001     119
# 2000      67
# 1996      46
# 2016      41
# 1999      39
# 1995      31
# 2017      29
# 1998      28
# 1994      22
# 1992      17
# 1987      15
# 1993      15
# 1988      13
# 1997      13
# 1985      12
# 1989      12
# 1991      12
# 2018      10
# 1990       9
# 1986       8
# 2019       5
# 1983       4
# 1984       4
# 1982       1
# Name: year_graduated, dtype: int64

# %%
df_train['year_graduated'].value_counts().sort_index()
# Out:
# 1982       1
# 1983       4
# 1984       4
# 1985      12
# 1986       8
# 1987      15
# 1988      13
# 1989      12
# 1990       9
# 1991      12
# 1992      17
# 1993      15
# 1994      22
# 1995      31
# 1996      46
# 1997      13
# 1998      28
# 1999      39
# 2000      67
# 2001     119
# 2002     172
# 2003     255
# 2004     278
# 2005     295
# 2006     421
# 2007     670
# 2008    1069
# 2009    1204
# 2010    1531
# 2011    1693
# 2012    1339
# 2013     875
# 2014     616
# 2015     163
# 2016      41
# 2017      29
# 2018      10
# 2019       5
# Name: year_graduated, dtype: int64

# %%
df_test['year_graduated'].value_counts().sort_index()
# Out:
# 1984      1
# 1985      1
# 1986      8
# 1987      6
# 1988      8
# 1989      5
# 1990      6
# 1991      4
# 1992      6
# 1993     13
# 1994     17
# 1995     10
# 1996     15
# 1997      6
# 1998     19
# 1999     23
# 2000     32
# 2001     64
# 2002    116
# 2003    118
# 2004    151
# 2005    163
# 2006    212
# 2007    339
# 2008    556
# 2009    697
# 2010    816
# 2011    932
# 2012    756
# 2013    463
# 2014    316
# 2015     76
# 2016     23
# 2017     15
# 2018      5
# 2019      1
# 2020      1
# Name: year_graduated, dtype: int64

# %%
df_train['Education_level'].value_counts()
# Out:
# level_4    9222
# level_3    1743
# level_1     140
# level_5      43
# level_2       4
# level_0       1
# Name: Education_level, dtype: int64

# %%
df_train[df_train['GPA'] == 0]['Education_level'].value_counts()
# Out:
# level_4    1716
# level_3     321
# level_1     105
# level_5       4
# level_2       2
# Name: Education_level, dtype: int64

# %%
df_train[df_train['GPA'] == 0].shape
# Out:
# (2148, 22)

# %%
df_test[df_test['GPA'] == 0].shape
# Out:
# (1165, 21)

# %% [markdown]
# > ## Numeric Var

# %%
numeric_var = df_train.columns[df_train.dtypes != object]

# %%
numeric_var
# Out:
# Index(['job_duration_in_current_job_level',
#        'job_duration_in_current_person_level',
#        'job_duration_in_current_branch', 'gender', 'age',
#        'number_of_dependences', 'GPA', 'year_graduated',
#        'job_duration_from_training', 'branch_rotation', 'job_rotation',
#        'assign_of_otherposition', 'annual leave', 'sick_leaves',
#        'Last_achievement_%', 'Achievement_above_100%_during3quartal',
#        'Best Performance'],
#       dtype='object')

# %%
df_train[numeric_var].describe()
# Out:
#        job_duration_in_current_job_level  \
# count                       11153.000000
# mean                            1.433208
# std                             0.431086
# min                             0.000000
# 25%                             1.224745
# 50%                             1.352775
# 75%                             1.414214
# max                             2.958040
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# count                          11153.000000                    11153.000000
# mean                               1.349218                        1.034646
# std                                0.324660                        0.416723
# min                                0.000000                        0.000000
# 25%                                1.224745                        0.707107
# 50%                                1.352775                        1.118034
# 75%                                1.385641                        1.224745
# max                                2.828427                        2.677686
#
#              gender           age  number_of_dependences           GPA  \
# count  11153.000000  11153.000000           11153.000000  11153.000000
# mean       1.735587   1985.837084               0.995517      3.176195
# std        0.441040      4.632214               0.881103     13.321687
# min        1.000000   1963.000000               0.000000      0.000000
# 25%        1.000000   1985.000000               0.000000      2.820000
# 50%        2.000000   1987.000000               1.000000      3.070000
# 75%        2.000000   1989.000000               2.000000      3.270000
# max        2.000000   1997.000000               7.000000    378.000000
#
#        year_graduated  job_duration_from_training  branch_rotation  \
# count    11153.000000                11153.000000     11153.000000
# mean      2009.174124                    6.277952         3.720165
# std          4.117162                    5.033553         2.399068
# min       1982.000000                    2.000000         1.000000
# 25%       2008.000000                    4.000000         2.000000
# 50%       2010.000000                    5.000000         3.000000
# 75%       2012.000000                    6.000000         4.000000
# max       2019.000000                   36.000000        22.000000
#
#        job_rotation  assign_of_otherposition  annual leave   sick_leaves  \
# count  11153.000000             11153.000000  11153.000000  11153.000000
# mean       3.505694                 1.202726      3.664216      1.100152
# std        1.818028                 2.575138      2.652648      2.714525
# min        1.000000                 0.000000      0.000000      0.000000
# 25%        2.000000                 0.000000      2.000000      0.000000
# 50%        3.000000                 0.000000      3.000000      0.000000
# 75%        4.000000                 1.000000      5.000000      1.000000
# max       15.000000                29.000000     21.000000     77.000000
#
#        Last_achievement_%  Achievement_above_100%_during3quartal  \
# count        11152.000000                           11152.000000
# mean            72.234902                               0.679071
# std             23.030421                               1.107381
# min              4.510000                               0.000000
# 25%             56.650000                               0.000000
# 50%             71.675000                               0.000000
# 75%             88.172500                               1.000000
# max            130.000000                               3.000000
#
#        Best Performance
# count      11153.000000
# mean           0.146777
# std            0.353899
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
df_train[numeric_var].hist(figsize = (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015E86FB4240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E874B6D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E874F2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87521A20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015E8755E0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E8758E710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E875C0D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E875FD3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015E875FD438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E8766A0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E8769D748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E876CCDA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015E8770A438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87738A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87777128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E877AB780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015E877DADD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87818470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87848AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87888160>]],
#       dtype=object)

# %%
# df_test[numeric_var].hist(figsize = (20,20))

# %%
# numeric_discrete = ['age', 'number_of_dependences',
#        'number_of_dependences (male)', 'number_of_dependences (female)', 'GPA',
#        'branch_rotation', 'job_rotation', 'assign_of_otherposition',
#        'annual leave', 'sick_leaves', 'Achievement_above_100%_during3quartal']

# %% [markdown]
# > ## Age

# %%
df_train['age'].value_counts()
# Out:
# 1988    1558
# 1987    1473
# 1986    1348
# 1989    1323
# 1985     954
# 1990     926
# 1984     654
# 1991     511
# 1983     472
# 1982     286
# 1981     240
# 1980     228
# 1992     192
# 1979     154
# 1978     121
# 1977      92
# 1976      73
# 1993      55
# 1975      55
# 1974      47
# 1973      45
# 1968      44
# 1969      41
# 1971      38
# 1970      38
# 1972      35
# 1967      35
# 1964      29
# 1965      27
# 1966      25
# 1994      16
# 1995       7
# 1963       6
# 1996       4
# 1997       1
# Name: age, dtype: int64

# %% [markdown]
# > ## GPA

# %%
df_train['GPA'].value_counts()
# Out:
# 0.00     2148
# 3.00      382
# 3.01      229
# 3.10      199
# 3.03      186
#          ...
# 75.00       1
# 2.31        1
# 2.54        1
# 22.00       1
# 2.10        1
# Name: GPA, Length: 216, dtype: int64

# %%
df_train['GPA'].describe()
# Out:
# count    11153.000000
# mean         3.176195
# std         13.321687
# min          0.000000
# 25%          2.820000
# 50%          3.070000
# 75%          3.270000
# max        378.000000
# Name: GPA, dtype: float64

# %%
np.sort(df_train[~df_train['GPA'].isnull()]['GPA'])
# Out:
# array([  0.,   0.,   0., ..., 331., 368., 378.])

# %% [markdown]
# # Job Level

# %%
df_train.head(10)
# Out:
#   job_level  job_duration_in_current_job_level person_level  \
# 0      JG04                           1.352775         PG03
# 1      JG04                           1.292285         PG03
# 2      JG05                           2.565151         PG06
# 3      JG05                           2.828427         PG06
# 4      JG05                           2.828427         PG06
# 5      JG05                           2.828427         PG06
# 6      JG05                           2.828427         PG06
# 7      JG05                           2.828427         PG06
# 8      JG04                           1.118034         PG03
# 9      JG04                           1.118034         PG03
#
#    job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                              1.352775                        1.732051
# 1                              1.292285                        1.039230
# 2                              2.308679                        1.780449
# 3                              1.000000                        1.385641
# 4                              2.828427                        0.707107
# 5                              2.121320                        1.118034
# 6                              2.345208                        2.102380
# 7                              2.236068                        1.581139
# 8                              1.118034                        0.412311
# 9                              1.118034                        0.412311
#
#   Employee_type  gender   age marital_status_maried(Y/N)  \
# 0     RM_type_A       2  1985                          Y
# 1     RM_type_A       2  1989                          Y
# 2     RM_type_C       1  1970                          Y
# 3     RM_type_A       2  1967                          Y
# 4     RM_type_A       2  1965                          Y
# 5     RM_type_A       1  1971                          Y
# 6     RM_type_A       1  1969                          Y
# 7     RM_type_C       2  1968                          Y
# 8     RM_type_B       1  1989                          Y
# 9     RM_type_B       2  1991                          N
#
#    number_of_dependences Education_level   GPA  year_graduated  \
# 0                      1         level_0  2.86            2011
# 1                      0         level_1  7.28            2007
# 2                      1         level_1  0.00            1989
# 3                      2         level_1  0.00            1987
# 4                      3         level_1  7.20            1985
# 5                      3         level_1  0.00            1990
# 6                      2         level_1  0.00            1988
# 7                      2         level_1  0.00            1987
# 8                      0         level_1  3.01            2007
# 9                      0         level_1  4.19            2009
#
#    job_duration_from_training  branch_rotation  job_rotation  \
# 0                           4                2             3
# 1                           4                4             3
# 2                          28               10             9
# 3                          29               11             6
# 4                          30                9             8
# 5                          28                7             9
# 6                          29                8             6
# 7                          29                6             8
# 8                           3                2             2
# 9                           3                2             2
#
#    assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                        2             3            0               46.37
# 1                        0             0            1               47.68
# 2                        6             2            1               40.73
# 3                        0             4           10               47.42
# 4                        2             3            0               47.18
# 5                        4             0            0               48.46
# 6                        2             8            0               60.38
# 7                        1             3            4               14.71
# 8                        0             9            0               26.76
# 9                        0             3            0               41.45
#
#    Achievement_above_100%_during3quartal  Best Performance
# 0                                    0.0                 0
# 1                                    0.0                 0
# 2                                    0.0                 0
# 3                                    0.0                 1
# 4                                    0.0                 0
# 5                                    0.0                 0
# 6                                    0.0                 0
# 7                                    0.0                 0
# 8                                    0.0                 0
# 9                                    0.0                 1

# %%
df_train[df_train['job_duration_in_current_job_level'] < df_train['job_duration_in_current_person_level']]
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 41         JG04                           2.738613         PG04
# 81         JG05                           1.936492         PG06
# 108        JG05                           2.236068         PG06
# 126        JG04                           2.565151         PG04
# 1311       JG04                           2.465766         PG04
# 1811       JG05                           2.613427         PG06
# 1866       JG05                           2.598076         PG06
# 2133       JG04                           0.648074         PG03
# 3157       JG05                           1.936492         PG07
# 3709       JG05                           2.707397         PG06
# 3752       JG05                           2.042058         PG07
# 3984       JG04                           2.798214         PG04
# 3985       JG05                           2.042058         PG06
# 4908       JG04                           2.345208         PG05
# 5246       JG05                           2.645751         PG07
# 5264       JG05                           2.707397         PG07
# 6352       JG05                           2.692582         PG06
# 7356       JG04                           1.352775         PG04
# 7716       JG04                           2.515949         PG04
# 8997       JG04                           2.253886         PG04
# 9061       JG03                           0.000000         PG03
# 9827       JG04                           2.613427         PG04
# 10010      JG04                           1.039230         PG03
# 10476      JG05                           1.915724         PG06
# 10633      JG05                           2.465766         PG07
# 10729      JG04                           2.253886         PG04
# 10882      JG05                           2.582634         PG06
# 10891      JG04                           2.613427         PG04
# 10973      JG05                           2.598076         PG06
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 41                                 2.828427                        0.707107
# 81                                 2.828427                        1.224745
# 108                                2.828427                        1.224745
# 126                                2.828427                        1.581139
# 1311                               2.828427                        0.707107
# 1811                               2.828427                        0.707107
# 1866                               2.828427                        1.682260
# 2133                               1.224745                        0.707107
# 3157                               2.500000                        1.224745
# 3709                               2.828427                        0.707107
# 3752                               2.465766                        0.707107
# 3984                               2.828427                        0.648074
# 3985                               2.828427                        0.648074
# 4908                               2.500000                        0.707107
# 5246                               2.769476                        1.224745
# 5264                               2.828427                        0.000000
# 6352                               2.828427                        1.191638
# 7356                               2.197726                        0.707107
# 7716                               2.828427                        0.707107
# 8997                               2.828427                        1.555635
# 9061                               1.385641                        0.000000
# 9827                               2.828427                        0.648074
# 10010                              1.936492                        0.000000
# 10476                              2.828427                        1.224745
# 10633                              2.814249                        0.707107
# 10729                              2.828427                        0.707107
# 10882                              2.828427                        1.224745
# 10891                              2.828427                        1.224745
# 10973                              2.828427                        1.224745
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 41        RM_type_A       2  1965                          Y
# 81        RM_type_A       2  1965                          Y
# 108       RM_type_A       1  1969                          Y
# 126       RM_type_A       1  1973                          Y
# 1311      RM_type_C       1  1973                          Y
# 1811      RM_type_A       1  1964                          Y
# 1866      RM_type_A       1  1965                          Y
# 2133      RM_type_B       2  1990                          N
# 3157      RM_type_A       2  1978                          Y
# 3709      RM_type_A       1  1968                          Y
# 3752      RM_type_A       2  1977                          Y
# 3984      RM_type_A       1  1977                          Y
# 3985      RM_type_A       1  1969                          Y
# 4908      RM_type_A       2  1986                          Y
# 5246      RM_type_A       2  1970                          Y
# 5264      RM_type_C       1  1964                          Y
# 6352      RM_type_A       1  1967                          Y
# 7356      RM_type_A       1  1969                          Y
# 7716      RM_type_C       1  1966                          Y
# 8997      RM_type_A       1  1970                          Y
# 9061      RM_type_A       2  1989                          Y
# 9827      RM_type_A       1  1967                          Y
# 10010     RM_type_B       2  1978                          Y
# 10476     RM_type_A       1  1965                          Y
# 10633     RM_type_A       2  1971                          Y
# 10729     RM_type_A       1  1973                          Y
# 10882     RM_type_A       1  1970                          Y
# 10891     RM_type_A       1  1974                          Y
# 10973     RM_type_A       1  1965                          Y
#
#        number_of_dependences Education_level     GPA  year_graduated  \
# 41                         2         level_1    0.00            1986
# 81                         3         level_1    0.00            1985
# 108                        3         level_1  155.00            1988
# 126                        3         level_1    0.00            1992
# 1311                       1         level_3    2.70            1994
# 1811                       2         level_3    0.00            1989
# 1866                       3         level_3    0.00            1989
# 2133                       0         level_4    3.47            2013
# 3157                       3         level_4    0.00            2002
# 3709                       3         level_4    3.22            2004
# 3752                       3         level_4    3.21            1999
# 3984                       3         level_4    0.30            2014
# 3985                       2         level_4    3.18            2006
# 4908                       1         level_4    3.19            2010
# 5246                       3         level_4    0.00            1996
# 5264                       3         level_4    0.00            2002
# 6352                       2         level_4    0.00            1991
# 7356                       2         level_4    0.00            2005
# 7716                       3         level_4    2.78            1996
# 8997                       3         level_4    2.89            1989
# 9061                       0         level_4    3.33            2012
# 9827                       2         level_4    3.05            2003
# 10010                      1         level_4    3.42            2001
# 10476                      3         level_4    0.00            2004
# 10633                      3         level_4    3.11            2010
# 10729                      3         level_4    2.76            2004
# 10882                      2         level_4    3.21            2003
# 10891                      3         level_4    3.16            2007
# 10973                      3         level_4    2.99            2006
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 41                             30                5            10
# 81                             30                8             6
# 108                            30                7             7
# 126                            25               19             8
# 1311                           26                9             7
# 1811                           29               11             8
# 1866                           29                9            11
# 2133                            3                2             2
# 3157                           16               13             8
# 3709                           31                9             6
# 3752                           18               10             9
# 3984                           26               13             6
# 3985                           30               17            10
# 4908                            6                5             5
# 5246                           22                8             7
# 5264                           30               15             9
# 6352                           25                8             7
# 7356                           31               14            11
# 7716                           29               14             8
# 8997                           28                8             7
# 9061                            5                5             4
# 9827                           26               11            10
# 10010                          17               11             8
# 10476                          30                7            11
# 10633                          24               11             9
# 10729                          26               10             9
# 10882                          30                9             9
# 10891                          25                7             9
# 10973                          29               13            10
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 41                           0            10           11               28.33
# 81                           0             3            1               46.72
# 108                          0             6            0               73.24
# 126                          0             0            1               65.38
# 1311                         0             0            0              102.12
# 1811                         7            10            2               82.30
# 1866                         0             6            3               68.63
# 2133                         0             1            4               13.77
# 3157                         1             3            0               13.40
# 3709                         4             2            0               86.84
# 3752                         2             9            0               96.13
# 3984                         1             0            1               99.51
# 3985                         1             3            0               65.08
# 4908                         0             2            1               51.68
# 5246                         0             3            0               67.67
# 5264                         0             5            5               76.65
# 6352                         0             1            0               89.20
# 7356                        12             0            0               88.44
# 7716                         1            12            4               57.91
# 8997                         0             3            0               52.51
# 9061                         0             2            1               58.01
# 9827                         2             3            0               79.08
# 10010                        0             3            0               86.96
# 10476                        2             7            6               91.48
# 10633                        1             4            3               95.33
# 10729                        1             3            0               90.26
# 10882                        9             3            0              109.72
# 10891                        0             8            0              107.50
# 10973                        2             6            0               87.07
#
#        Achievement_above_100%_during3quartal  Best Performance
# 41                                       0.0                 0
# 81                                       0.0                 0
# 108                                      0.0                 0
# 126                                      0.0                 0
# 1311                                     3.0                 0
# 1811                                     0.0                 0
# 1866                                     0.0                 0
# 2133                                     0.0                 0
# 3157                                     1.0                 0
# 3709                                     2.0                 1
# 3752                                     2.0                 0
# 3984                                     2.0                 0
# 3985                                     0.0                 0
# 4908                                     0.0                 0
# 5246                                     0.0                 0
# 5264                                     0.0                 0
# 6352                                     2.0                 1
# 7356                                     2.0                 1
# 7716                                     0.0                 1
# 8997                                     0.0                 0
# 9061                                     0.0                 0
# 9827                                     0.0                 0
# 10010                                    1.0                 0
# 10476                                    1.0                 0
# 10633                                    3.0                 0
# 10729                                    2.0                 0
# 10882                                    3.0                 1
# 10891                                    3.0                 0
# 10973                                    1.0                 0

# %%
pd.crosstab(df_test['job_level'],df_test['person_level'])
# Out:
# person_level  PG01  PG02  PG03  PG04  PG05  PG06  PG07
# job_level
# JG03             6     5     0     0     0     0     0
# JG04             0     0  5211   403     0     2     0
# JG05             0     0     0     0   159   201    12
# JG06             0     0     0     0     0     0     1

# %%
df_train[(df_train['job_level']=='JG04')&(df_train['person_level']=='PG04')]
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 23         JG04                           2.828427         PG04
# 41         JG04                           2.738613         PG04
# 50         JG04                           2.828427         PG04
# 73         JG04                           2.828427         PG04
# 75         JG04                           2.828427         PG04
# ...         ...                                ...          ...
# 11113      JG04                           2.397916         PG04
# 11120      JG04                           2.465766         PG04
# 11125      JG04                           2.814249         PG04
# 11136      JG04                           2.828427         PG04
# 11152      JG04                           2.828427         PG04
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 23                                 2.828427                        1.682260
# 41                                 2.828427                        0.707107
# 50                                 2.236068                        0.866025
# 73                                 2.828427                        1.224745
# 75                                 2.121320                        0.000000
# ...                                     ...                             ...
# 11113                              1.224745                        1.224745
# 11120                              1.732051                        0.000000
# 11125                              2.000000                        0.574456
# 11136                              1.224745                        0.412311
# 11152                              2.121320                        1.473092
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 23        RM_type_A       2  1964                          Y
# 41        RM_type_A       2  1965                          Y
# 50        RM_type_A       2  1969                          Y
# 73        RM_type_A       1  1965                          Y
# 75        RM_type_A       2  1976                          Y
# ...             ...     ...   ...                        ...
# 11113     RM_type_A       1  1980                          Y
# 11120     RM_type_C       1  1982                          Y
# 11125     RM_type_A       2  1986                          Y
# 11136     RM_type_A       2  1978                          Y
# 11152     RM_type_B       2  1980                          Y
#
#        number_of_dependences Education_level   GPA  year_graduated  \
# 23                         3         level_1  0.00            1983
# 41                         2         level_1  0.00            1986
# 50                         4         level_1  0.00            1987
# 73                         2         level_1  0.00            1985
# 75                         2         level_1  0.00            1995
# ...                      ...             ...   ...             ...
# 11113                      3         level_5  3.34            2006
# 11120                      1         level_5  3.35            2010
# 11125                      0         level_5  3.63            2017
# 11136                      2         level_5  3.19            2005
# 11152                      2         level_5  3.14            2009
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 23                             34                9             9
# 41                             30                5            10
# 50                             28               13             8
# 73                             28                9             8
# 75                             23                8             9
# ...                           ...              ...           ...
# 11113                          14                8             6
# 11120                          13               11             8
# 11125                           8                7             4
# 11136                          15               10             8
# 11152                          14                5             7
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 23                           0             3            2               46.56
# 41                           0            10           11               28.33
# 50                           1             3            0               88.74
# 73                           0             3            0               76.50
# 75                           2             0            0               45.55
# ...                        ...           ...          ...                 ...
# 11113                        0             3            3               45.50
# 11120                        0            12           14               65.13
# 11125                        0             6            2               58.80
# 11136                        6             8            1               60.10
# 11152                        0             2            0               79.99
#
#        Achievement_above_100%_during3quartal  Best Performance
# 23                                       0.0                 0
# 41                                       0.0                 0
# 50                                       2.0                 0
# 73                                       0.0                 1
# 75                                       0.0                 0
# ...                                      ...               ...
# 11113                                    0.0                 0
# 11120                                    1.0                 1
# 11125                                    0.0                 0
# 11136                                    1.0                 1
# 11152                                    1.0                 0
#
# [757 rows x 22 columns]

# %% [markdown]
# # Anomaly

# %% [markdown]
# > ## Eduacation

# %%
df_train['Education_level'].value_counts()
# Out:
# level_4    9222
# level_3    1743
# level_1     140
# level_5      43
# level_2       4
# level_0       1
# Name: Education_level, dtype: int64

# %%
df_train['Education_level'].isnull().sum()
# Out:
# 0

# %%
df_train[['Education_level','GPA']][df_train['Education_level'] == 'level_0']
# Out:
#   Education_level   GPA
# 0         level_0  2.86

# %%
df_train[['Education_level','GPA']][df_train['Education_level'] == 'level_1'].describe()
# Out:
#               GPA
# count  140.000000
# mean     6.766000
# std     18.977287
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.740000
# max    155.000000

# %%
df_train[['Education_level','GPA']][df_train['GPA']>50]
# Out:
#       Education_level     GPA
# 68            level_1   75.00
# 78            level_1   53.06
# 108           level_1  155.00
# 134           level_1   66.00
# 1308          level_3  293.00
# 1986          level_4  285.00
# 2868          level_4  303.00
# 3560          level_4  327.00
# 4300          level_4  318.00
# 4950          level_4  330.00
# 5008          level_4  317.00
# 5238          level_4  315.00
# 5239          level_4  313.00
# 5241          level_4  301.00
# 5243          level_4  331.00
# 6221          level_4  325.00
# 6469          level_4  180.00
# 6473          level_4  280.00
# 7452          level_4  302.00
# 7476          level_4  282.00
# 7479          level_4  320.00
# 8275          level_4  322.00
# 10017         level_4  368.00
# 10377         level_4  378.00

# %%
df_train[['Education_level','GPA']][df_train['GPA']>4]
# Out:
#       Education_level     GPA
# 1             level_1    7.28
# 4             level_1    7.20
# 9             level_1    4.19
# 12            level_1    8.30
# 15            level_1    6.82
# 16            level_1    7.82
# 17            level_1    7.00
# 21            level_1    8.69
# 36            level_1   45.00
# 37            level_1   45.29
# 38            level_1   44.83
# 40            level_1    8.10
# 42            level_1   30.73
# 52            level_1   43.57
# 64            level_1    6.18
# 66            level_1   32.12
# 68            level_1   75.00
# 78            level_1   53.06
# 86            level_1    7.00
# 89            level_1   25.87
# 90            level_1    7.49
# 91            level_1   13.40
# 93            level_1    6.36
# 95            level_1   43.03
# 103           level_1    8.40
# 107           level_1   22.00
# 108           level_1  155.00
# 127           level_1   36.30
# 130           level_1   47.35
# 132           level_1   44.56
# 134           level_1   66.00
# 138           level_1   13.43
# 1308          level_3  293.00
# 1986          level_4  285.00
# 2868          level_4  303.00
# 3560          level_4  327.00
# 4300          level_4  318.00
# 4950          level_4  330.00
# 5008          level_4  317.00
# 5238          level_4  315.00
# 5239          level_4  313.00
# 5241          level_4  301.00
# 5243          level_4  331.00
# 6221          level_4  325.00
# 6469          level_4  180.00
# 6473          level_4  280.00
# 7452          level_4  302.00
# 7476          level_4  282.00
# 7479          level_4  320.00
# 8275          level_4  322.00
# 10017         level_4  368.00
# 10377         level_4  378.00

# %%
df_test[['Education_level','GPA']][df_test['GPA']>4]
# Out:
#      Education_level     GPA
# 160          level_4  312.00
# 344          level_4  294.00
# 1153         level_1    8.29
# 1200         level_1    8.50
# 1573         level_4  353.00
# 1608         level_4  270.00
# 1747         level_4  310.00
# 1956         level_1   48.53
# 2674         level_1   32.13
# 2867         level_4  296.00
# 3216         level_4  345.00
# 3239         level_1    7.85
# 3323         level_4  334.00
# 3348         level_4  299.00
# 3355         level_1   73.00
# 3614         level_1   31.59
# 3661         level_5  362.00
# 3967         level_1   34.40
# 4311         level_1   43.71
# 4546         level_4  317.00
# 4630         level_1    8.41
# 5115         level_3  116.00
# 5494         level_4    6.60
# 5548         level_1    6.00
# 5572         level_1    7.11
# 5590         level_4  381.00
# 5715         level_1    7.46
# 5743         level_1   48.61
# 5823         level_1    6.60
# 5834         level_1   53.70
# 5843         level_1    7.50

# %%
df_train[df_train['GPA'] == 0]
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 2          JG05                           2.565151         PG06
# 3          JG05                           2.828427         PG06
# 5          JG05                           2.828427         PG06
# 6          JG05                           2.828427         PG06
# 7          JG05                           2.828427         PG06
# ...         ...                                ...          ...
# 11108      JG04                           2.828427         PG04
# 11115      JG04                           1.118034         PG03
# 11127      JG04                           1.224745         PG03
# 11135      JG04                           1.224745         PG03
# 11147      JG04                           1.385641         PG03
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 2                                  2.308679                        1.780449
# 3                                  1.000000                        1.385641
# 5                                  2.121320                        1.118034
# 6                                  2.345208                        2.102380
# 7                                  2.236068                        1.581139
# ...                                     ...                             ...
# 11108                              2.449490                        1.224745
# 11115                              1.118034                        1.526434
# 11127                              1.224745                        0.000000
# 11135                              1.224745                        0.707107
# 11147                              1.385641                        0.707107
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 2         RM_type_C       1  1970                          Y
# 3         RM_type_A       2  1967                          Y
# 5         RM_type_A       1  1971                          Y
# 6         RM_type_A       1  1969                          Y
# 7         RM_type_C       2  1968                          Y
# ...             ...     ...   ...                        ...
# 11108     RM_type_A       2  1968                          Y
# 11115     RM_type_B       1  1989                          Y
# 11127     RM_type_B       2  1982                          Y
# 11135     RM_type_B       1  1986                          N
# 11147     RM_type_A       2  1985                          Y
#
#        number_of_dependences Education_level  GPA  year_graduated  \
# 2                          1         level_1  0.0            1989
# 3                          2         level_1  0.0            1987
# 5                          3         level_1  0.0            1990
# 6                          2         level_1  0.0            1988
# 7                          2         level_1  0.0            1987
# ...                      ...             ...  ...             ...
# 11108                      1         level_4  0.0            1996
# 11115                      0         level_5  0.0            2014
# 11127                      1         level_5  0.0            2009
# 11135                      0         level_5  0.0            2013
# 11147                      1         level_5  0.0            2014
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 2                              28               10             9
# 3                              29               11             6
# 5                              28                7             9
# 6                              29                8             6
# 7                              29                6             8
# ...                           ...              ...           ...
# 11108                          22                8             7
# 11115                           2                1             2
# 11127                           6                4             2
# 11135                           4                3             2
# 11147                           6                3             3
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 2                            6             2            1               40.73
# 3                            0             4           10               47.42
# 5                            4             0            0               48.46
# 6                            2             8            0               60.38
# 7                            1             3            4               14.71
# ...                        ...           ...          ...                 ...
# 11108                        2             3            0               99.38
# 11115                        0             5            1               41.53
# 11127                        0             4            0               52.74
# 11135                        0             2            0               39.00
# 11147                        0             3            0               82.39
#
#        Achievement_above_100%_during3quartal  Best Performance
# 2                                        0.0                 0
# 3                                        0.0                 1
# 5                                        0.0                 0
# 6                                        0.0                 0
# 7                                        0.0                 0
# ...                                      ...               ...
# 11108                                    3.0                 0
# 11115                                    0.0                 0
# 11127                                    0.0                 0
# 11135                                    0.0                 0
# 11147                                    0.0                 0
#
# [2148 rows x 22 columns]

# %% [markdown]
# > ## Age

# %%
df_test['age'].value_counts()
# Out:
# 1987    838
# 1988    819
# 1989    757
# 1986    643
# 1985    535
# 1990    503
# 1984    361
# 1991    285
# 1983    215
# 1982    150
# 1981    142
# 1979    116
# 1992    113
# 1980    111
# 1978     87
# 1977     44
# 1993     32
# 1976     28
# 1971     27
# 1975     25
# 1970     22
# 1968     21
# 1972     19
# 1973     19
# 1974     18
# 1965     15
# 1967     15
# 1969     13
# 1994     10
# 1966      8
# 1964      6
# 1963      2
# 1995      1
# Name: age, dtype: int64

# %%
df_train['age'].value_counts()
# Out:
# 1988    1558
# 1987    1473
# 1986    1348
# 1989    1323
# 1985     954
# 1990     926
# 1984     654
# 1991     511
# 1983     472
# 1982     286
# 1981     240
# 1980     228
# 1992     192
# 1979     154
# 1978     121
# 1977      92
# 1976      73
# 1993      55
# 1975      55
# 1974      47
# 1973      45
# 1968      44
# 1969      41
# 1971      38
# 1970      38
# 1972      35
# 1967      35
# 1964      29
# 1965      27
# 1966      25
# 1994      16
# 1995       7
# 1963       6
# 1996       4
# 1997       1
# Name: age, dtype: int64

# %% [markdown]
# > ## Year Graduated

# %%
df_train['year_graduated'].value_counts().sort_index()
# Out:
# 1982       1
# 1983       4
# 1984       4
# 1985      12
# 1986       8
# 1987      15
# 1988      13
# 1989      12
# 1990       9
# 1991      12
# 1992      17
# 1993      15
# 1994      22
# 1995      31
# 1996      46
# 1997      13
# 1998      28
# 1999      39
# 2000      67
# 2001     119
# 2002     172
# 2003     255
# 2004     278
# 2005     295
# 2006     421
# 2007     670
# 2008    1069
# 2009    1204
# 2010    1531
# 2011    1693
# 2012    1339
# 2013     875
# 2014     616
# 2015     163
# 2016      41
# 2017      29
# 2018      10
# 2019       5
# Name: year_graduated, dtype: int64

# %% [markdown]
# > ## dependents

# %%
df_train.columns
# Out:
# Index(['job_level', 'job_duration_in_current_job_level', 'person_level',
#        'job_duration_in_current_person_level',
#        'job_duration_in_current_branch', 'Employee_type', 'gender', 'age',
#        'marital_status_maried(Y/N)', 'number_of_dependences',
#        'Education_level', 'GPA', 'year_graduated',
#        'job_duration_from_training', 'branch_rotation', 'job_rotation',
#        'assign_of_otherposition', 'annual leave', 'sick_leaves',
#        'Last_achievement_%', 'Achievement_above_100%_during3quartal',
#        'Best Performance'],
#       dtype='object')

# %% [markdown]
# > ## Leave

# %%
df_train[['annual leave','sick_leaves']].describe()
# Out:
#        annual leave   sick_leaves
# count  11153.000000  11153.000000
# mean       3.664216      1.100152
# std        2.652648      2.714525
# min        0.000000      0.000000
# 25%        2.000000      0.000000
# 50%        3.000000      0.000000
# 75%        5.000000      1.000000
# max       21.000000     77.000000

# %%
df_train[['annual leave','sick_leaves']].hist(figsize = (10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87CCDBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E87D088D0>]],
#       dtype=object)

# %%
df_train[['annual leave','sick_leaves']].sort_values(by = 'annual leave').tail(20)
# Out:
#       annual leave  sick_leaves
# 6795            15            0
# 643             15            0
# 1203            15           15
# 3891            15            0
# 2495            15            4
# 5004            15            0
# 258             15            0
# 1164            15            0
# 1166            16            9
# 6983            16            0
# 4517            16            0
# 2789            16            2
# 2377            16            6
# 7560            18            0
# 7924            18            0
# 3523            18            0
# 3559            18            0
# 457             19            3
# 2521            20            3
# 9891            21            0

# %%
df_train[['annual leave','sick_leaves']].sort_values(by = 'sick_leaves').tail(20)
# Out:
#        annual leave  sick_leaves
# 4192              2           23
# 11042             0           25
# 4140              1           26
# 8482              3           27
# 2999              5           28
# 9304              3           28
# 8924              3           29
# 4078              7           29
# 3369              3           30
# 2979              9           30
# 8036             11           31
# 7093              3           32
# 7431              2           36
# 7534              2           37
# 6847              1           37
# 1317              8           46
# 6952              0           47
# 9732              0           53
# 3782              0           55
# 2714              4           77

# %% [markdown]
# > ## Achievement

# %% [markdown]
# # Data Prepaparation

# %%
df_train_prep1 = df_train.copy()
df_test_prep1 = df_test.copy()

# %%
# df_train_prep1 = df_train_prep1.dropna()
# df_train_prep1 = df_train_prep1[~df_train_prep1['Education_level'].isnull()]

# %%
df_train_prep1.shape
# Out:
# (11153, 22)

# %% [markdown]
# ## Training Set

# %% [markdown]
# ACHIEVEMENT

# %%
df_train_prep1['Achievement_above_100%_during3quartal'].fillna(0, inplace = True)

# %% [markdown]
# GPA

# %%
df_train_prep1['GPA'] = np.where(df_train_prep1['GPA']>100,df_train_prep1['GPA']/100,df_train_prep1['GPA'])
df_train_prep1['GPA'] = np.where(df_train_prep1['Education_level'].isin(['level_0','level_1']),0,df_train_prep1['GPA'])
df_train_prep1['GPA'] = np.where((df_train_prep1['GPA']==0)&(df_train_prep1['Education_level'] == 'level_4'),3,df_train_prep1['GPA'])

# %% [markdown]
# Job duration

# %% [markdown]
# RESULT

# %%
df_train_prep1.shape
# Out:
# (11153, 22)

# %%
df_train_prep1.head()
# Out:
#   job_level  job_duration_in_current_job_level person_level  \
# 0      JG04                           1.352775         PG03
# 1      JG04                           1.292285         PG03
# 2      JG05                           2.565151         PG06
# 3      JG05                           2.828427         PG06
# 4      JG05                           2.828427         PG06
#
#    job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                              1.352775                        1.732051
# 1                              1.292285                        1.039230
# 2                              2.308679                        1.780449
# 3                              1.000000                        1.385641
# 4                              2.828427                        0.707107
#
#   Employee_type  gender   age marital_status_maried(Y/N)  \
# 0     RM_type_A       2  1985                          Y
# 1     RM_type_A       2  1989                          Y
# 2     RM_type_C       1  1970                          Y
# 3     RM_type_A       2  1967                          Y
# 4     RM_type_A       2  1965                          Y
#
#    number_of_dependences Education_level  GPA  year_graduated  \
# 0                      1         level_0  0.0            2011
# 1                      0         level_1  0.0            2007
# 2                      1         level_1  0.0            1989
# 3                      2         level_1  0.0            1987
# 4                      3         level_1  0.0            1985
#
#    job_duration_from_training  branch_rotation  job_rotation  \
# 0                           4                2             3
# 1                           4                4             3
# 2                          28               10             9
# 3                          29               11             6
# 4                          30                9             8
#
#    assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                        2             3            0               46.37
# 1                        0             0            1               47.68
# 2                        6             2            1               40.73
# 3                        0             4           10               47.42
# 4                        2             3            0               47.18
#
#    Achievement_above_100%_during3quartal  Best Performance
# 0                                    0.0                 0
# 1                                    0.0                 0
# 2                                    0.0                 0
# 3                                    0.0                 1
# 4                                    0.0                 0

# %% [markdown]
# > ## Test Set

# %%
df_test_prep1['GPA'] = np.where(df_test['GPA']>100,df_test['GPA']/100,df_test['GPA'])
df_test_prep1['GPA'] = np.where(df_test_prep1['Education_level'].isin(['level_0','level_1']),0,df_test_prep1['GPA'])
df_test_prep1['GPA'] = np.where((df_test_prep1['GPA']==0)&(df_test_prep1['Education_level'] == 'level_4'),3,df_test_prep1['GPA'])

# %%
df_test_prep1.head()
# Out:
#   job_level  job_duration_in_current_job_level person_level  \
# 0      JG04                           1.256981         PG03
# 1      JG04                           1.224745         PG03
# 2      JG04                           0.500000         PG03
# 3      JG04                           1.256981         PG03
# 4      JG04                           1.352775         PG03
#
#    job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                              1.256981                        0.707107
# 1                              1.224745                        1.256981
# 2                              0.500000                        1.081665
# 3                              1.256981                        1.802776
# 4                              1.352775                        1.224745
#
#   Employee_type  gender   age marital_status_maried(Y/N)  \
# 0     RM_type_A       1  1988                          N
# 1     RM_type_B       2  1991                          N
# 2     RM_type_A       2  1989                          Y
# 3     RM_type_A       2  1990                          Y
# 4     RM_type_B       1  1985                          Y
#
#    number_of_dependences Education_level   GPA  year_graduated  \
# 0                      0         level_3  3.08            2009
# 1                      0         level_4  3.31            2014
# 2                      1         level_4  3.44            2011
# 3                      1         level_4  3.00            2014
# 4                      0         level_4  3.34            2007
#
#    job_duration_from_training  branch_rotation  job_rotation  \
# 0                           6                4             2
# 1                           2                2             2
# 2                           4                2             2
# 3                           3                1             3
# 4                           5                3             2
#
#    assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                        6             3            7               84.02
# 1                        0             1            0               63.74
# 2                        0             2            1               88.19
# 3                        0             3            0               25.94
# 4                        0             3            0               82.32
#
#    Achievement_above_100%_during3quartal
# 0                                    0.0
# 1                                    0.0
# 2                                    1.0
# 3                                    0.0
# 4                                    0.0

# %%
for i in object_var:
    print('train\n')
    print(df_train[i].value_counts().sort_index()/df_train[~df_train[i].isnull()].shape[0],'\n')
    print('test\n')
    print(df_test[i].value_counts().sort_index()/df_test.shape[0],'\n')
# Out:
# train
#
# JG03    0.003228
# JG04    0.933650
# JG05    0.063122
# Name: job_level, dtype: float64
#
# test
#
# JG03    0.001833
# JG04    0.936000
# JG05    0.062000
# JG06    0.000167
# Name: job_level, dtype: float64
#
# train
#
# PG01    0.001704
# PG02    0.001435
# PG03    0.865686
# PG04    0.067874
# PG05    0.027616
# PG06    0.033892
# PG07    0.001704
# PG08    0.000090
# Name: person_level, dtype: float64
#
# test
#
# PG01    0.001000
# PG02    0.000833
# PG03    0.868500
# PG04    0.067167
# PG05    0.026500
# PG06    0.033833
# PG07    0.002167
# Name: person_level, dtype: float64
#
# train
#
# RM_type_A    0.653367
# RM_type_B    0.303057
# RM_type_C    0.043576
# Name: Employee_type, dtype: float64
#
# test
#
# RM_type_A    0.645833
# RM_type_B    0.305167
# RM_type_C    0.049000
# Name: Employee_type, dtype: float64
#
# train
#
# N    0.148122
# Y    0.851878
# Name: marital_status_maried(Y/N), dtype: float64
#
# test
#
# N    0.148333
# Y    0.851667
# Name: marital_status_maried(Y/N), dtype: float64
#
# train
#
# level_0    0.000090
# level_1    0.012553
# level_2    0.000359
# level_3    0.156281
# level_4    0.826863
# level_5    0.003855
# Name: Education_level, dtype: float64
#
# test
#
# level_0    0.000167
# level_1    0.012500
# level_2    0.000333
# level_3    0.157333
# level_4    0.825000
# level_5    0.004667
# Name: Education_level, dtype: float64

# %%
for i in object_var:
    print('train\n')
    print(df_train_prep1[i].value_counts().sort_index()/df_train_prep1[~df_train_prep1[i].isnull()].shape[0],'\n')
    print('test\n')
    print(df_test_prep1[i].value_counts().sort_index()/df_test_prep1.shape[0],'\n')
# Out:
# train
#
# JG03    0.003228
# JG04    0.933650
# JG05    0.063122
# Name: job_level, dtype: float64
#
# test
#
# JG03    0.001833
# JG04    0.936000
# JG05    0.062000
# JG06    0.000167
# Name: job_level, dtype: float64
#
# train
#
# PG01    0.001704
# PG02    0.001435
# PG03    0.865686
# PG04    0.067874
# PG05    0.027616
# PG06    0.033892
# PG07    0.001704
# PG08    0.000090
# Name: person_level, dtype: float64
#
# test
#
# PG01    0.001000
# PG02    0.000833
# PG03    0.868500
# PG04    0.067167
# PG05    0.026500
# PG06    0.033833
# PG07    0.002167
# Name: person_level, dtype: float64
#
# train
#
# RM_type_A    0.653367
# RM_type_B    0.303057
# RM_type_C    0.043576
# Name: Employee_type, dtype: float64
#
# test
#
# RM_type_A    0.645833
# RM_type_B    0.305167
# RM_type_C    0.049000
# Name: Employee_type, dtype: float64
#
# train
#
# N    0.148122
# Y    0.851878
# Name: marital_status_maried(Y/N), dtype: float64
#
# test
#
# N    0.148333
# Y    0.851667
# Name: marital_status_maried(Y/N), dtype: float64
#
# train
#
# level_0    0.000090
# level_1    0.012553
# level_2    0.000359
# level_3    0.156281
# level_4    0.826863
# level_5    0.003855
# Name: Education_level, dtype: float64
#
# test
#
# level_0    0.000167
# level_1    0.012500
# level_2    0.000333
# level_3    0.157333
# level_4    0.825000
# level_5    0.004667
# Name: Education_level, dtype: float64

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# FE New variabel

# %%
# new_leaves (example)
df_train_prep1['total leave'] = df_train_prep1['annual leave'] + df_train_prep1['sick_leaves']
df_test_prep1['total leave'] = df_test_prep1['annual leave'] + df_test_prep1['sick_leaves']

# another ex. total transaksi/number of transaksion + - * /, ---> rule

# %% [markdown]
# Age

# %%
def age_2(x):
    if x <= 35:
        return 'ambis'
    elif x > 35:
        return 'non-ambis'
    
def age_3(x):
    if x <= 25:
        return 1
    elif x <= 35:
        return 2
    elif x <= 45:
        return 3
    elif x <= 55:
        return 4
    elif x <= 65:
        return 5

# %%
df_train_prep1['age2'] = 2020 - df_train_prep1['age']
df_train_prep1['age2'] = df_train_prep1['age2'].apply(age_2)
df_train_prep1['age2'].value_counts().sort_index()
# Out:
# ambis        8368
# non-ambis    2785
# Name: age2, dtype: int64

# %%
df_test_prep1['age2'] = 2020 - df_test_prep1['age']
df_test_prep1['age2'] = df_test_prep1['age2'].apply(age_2)
df_test_prep1['age2'].value_counts().sort_index()
# Out:
# ambis        4536
# non-ambis    1464
# Name: age2, dtype: int64

# %%
pd.crosstab(df_train_prep1['age2'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %%
df_train_prep1['age3'] = 2020 - df_train_prep1['age']
df_train_prep1['age3'] = df_train_prep1['age3'].apply(age_3)
df_train_prep1['age3'].value_counts().sort_index()
# Out:
# 1      12
# 2    8356
# 3    2375
# 4     375
# 5      35
# Name: age3, dtype: int64

# %%
df_test_prep1['age3'] = 2020 - df_test_prep1['age']
df_test_prep1['age3'] = df_test_prep1['age3'].apply(age_3)
df_test_prep1['age3'].value_counts().sort_index()
# Out:
# 1       1
# 2    4535
# 3    1279
# 4     177
# 5       8
# Name: age3, dtype: int64

# %%
pd.crosstab(df_train_prep1['age3'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %% [markdown]
# Year Graduated

# %%
def year_graduated_2(x):
    if x < 2000:
        return 'old'
    elif x < 2020:
        return 'new'
    else:
        return 'not grad'

# %%
df_train_prep1['year_graduated2'] = df_train_prep1['year_graduated'].apply(year_graduated_2)
df_test_prep1['year_graduated2'] = df_test_prep1['year_graduated'].apply(year_graduated_2)

# %%
pd.crosstab(df_train_prep1['year_graduated2'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %% [markdown]
# Total rotation

# %%
df_train_prep1['total_rotation'] = df_train_prep1['branch_rotation'] + df_train_prep1['job_rotation'] + df_train_prep1['assign_of_otherposition']
df_test_prep1['total_rotation'] = df_test_prep1['branch_rotation'] + df_test_prep1['job_rotation'] + df_test_prep1['assign_of_otherposition']

# %%
pd.crosstab(df_train_prep1['total_rotation'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %% [markdown]
# In Study

# %%
df_train_prep1['GPA'].hist()

# %%
df_train_prep1[(df_train_prep1['GPA'] == 0)&(df_train_prep1['Education_level'].isin(['level_3','level_4','level_5']))]
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 150        JG04                           1.385641         PG03
# 176        JG04                           0.707107         PG03
# 177        JG04                           1.606238         PG03
# 178        JG04                           1.352775         PG03
# 190        JG04                           1.224745         PG03
# ...         ...                                ...          ...
# 1880       JG04                           1.191638         PG03
# 11115      JG04                           1.118034         PG03
# 11127      JG04                           1.224745         PG03
# 11135      JG04                           1.224745         PG03
# 11147      JG04                           1.385641         PG03
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 150                                1.385641                        0.959166
# 176                                0.707107                        1.442221
# 177                                1.606238                        1.526434
# 178                                1.352775                        0.412311
# 190                                1.224745                        1.414214
# ...                                     ...                             ...
# 1880                               1.191638                        1.581139
# 11115                              1.118034                        1.526434
# 11127                              1.224745                        0.000000
# 11135                              1.224745                        0.707107
# 11147                              1.385641                        0.707107
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 150       RM_type_A       2  1984                          Y
# 176       RM_type_A       1  1985                          Y
# 177       RM_type_A       2  1986                          Y
# 178       RM_type_A       2  1985                          Y
# 190       RM_type_A       2  1988                          Y
# ...             ...     ...   ...                        ...
# 1880      RM_type_A       2  1988                          Y
# 11115     RM_type_B       1  1989                          Y
# 11127     RM_type_B       2  1982                          Y
# 11135     RM_type_B       1  1986                          N
# 11147     RM_type_A       2  1985                          Y
#
#        number_of_dependences Education_level  GPA  year_graduated  \
# 150                        0         level_3  0.0            2010
# 176                        0         level_3  0.0            2014
# 177                        2         level_3  0.0            2007
# 178                        2         level_3  0.0            2009
# 190                        0         level_3  0.0            2014
# ...                      ...             ...  ...             ...
# 1880                       0         level_3  0.0            2009
# 11115                      0         level_5  0.0            2014
# 11127                      1         level_5  0.0            2009
# 11135                      0         level_5  0.0            2013
# 11147                      1         level_5  0.0            2014
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 150                             7                4             4
# 176                             6                3             3
# 177                             6                3             3
# 178                             6                5             5
# 190                             3                2             3
# ...                           ...              ...           ...
# 1880                            5                2             2
# 11115                           2                1             2
# 11127                           6                4             2
# 11135                           4                3             2
# 11147                           6                3             3
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 150                         11             2            0               35.53
# 176                          0             3            0               93.86
# 177                          0             1            1               84.16
# 178                          0             4            0               61.75
# 190                          0             9            0               41.58
# ...                        ...           ...          ...                 ...
# 1880                         2             8            0               46.63
# 11115                        0             5            1               41.53
# 11127                        0             4            0               52.74
# 11135                        0             2            0               39.00
# 11147                        0             3            0               82.39
#
#        Achievement_above_100%_during3quartal  Best Performance  total leave  \
# 150                                      0.0                 0            2
# 176                                      1.0                 0            3
# 177                                      0.0                 0            2
# 178                                      0.0                 1            4
# 190                                      0.0                 0            9
# ...                                      ...               ...          ...
# 1880                                     0.0                 1            8
# 11115                                    0.0                 0            6
# 11127                                    0.0                 0            4
# 11135                                    0.0                 0            2
# 11147                                    0.0                 0            3
#
#             age2  age3 year_graduated2  total_rotation
# 150    non-ambis     3             new              19
# 176        ambis     2             new               6
# 177        ambis     2             new               6
# 178        ambis     2             new              10
# 190        ambis     2             new               5
# ...          ...   ...             ...             ...
# 1880       ambis     2             new               6
# 11115      ambis     2             new               3
# 11127  non-ambis     3             new               6
# 11135      ambis     2             new               5
# 11147      ambis     2             new               6
#
# [325 rows x 27 columns]

# %%
df_train_prep1['in study'] = np.where((df_train_prep1['GPA'] == 0)&(df_train_prep1['Education_level'].isin(['level_3','level_4','level_5'])),'study','finish')
df_test_prep1['in study'] = np.where((df_test_prep1['GPA'] == 0)&(df_test_prep1['Education_level'].isin(['level_3','level_4','level_5'])),'study','finish')

# %%
pd.crosstab(df_train_prep1['in study'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %% [markdown]
# person level up

# %%
df_train_prep1['person level up'] = np.where(df_train_prep1['job_duration_in_current_job_level']>df_train_prep1['job_duration_in_current_person_level'],'up','stay')
df_test_prep1['person level up'] = np.where(df_test_prep1['job_duration_in_current_job_level']>df_test_prep1['job_duration_in_current_person_level'],'up','stay')

# %%
pd.crosstab(df_train_prep1['person level up'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %% [markdown]
# leava or sick

# %%
df_train_prep1['sick_vs_leaves'] = np.where(df_train_prep1['annual leave']>df_train_prep1['sick_leaves'],'leave',np.where(df_train_prep1['annual leave']==df_train_prep1['sick_leaves'],'sama','sick'))
df_test_prep1['sick_vs_leaves'] = np.where(df_test_prep1['annual leave']>df_test_prep1['sick_leaves'],'leave',np.where(df_test_prep1['annual leave']==df_test_prep1['sick_leaves'],'sama','sick'))

# %%
pd.crosstab(df_train_prep1['sick_vs_leaves'],df_train_prep1['Best Performance'], normalize = 0)
# Out:
# Best Performance         0         1
# sick_vs_leaves
# leave             0.857309  0.142691
# sama              0.846154  0.153846
# sick              0.831461  0.168539

# %%
pd.crosstab(df_train_prep1['sick_vs_leaves'],df_train_prep1['Best Performance'], normalize = 0).plot(kind = 'bar')

# %% [markdown]
# age when graduated

# %%
df_train_prep1['Education_level'].value_counts()
# Out:
# level_4    9222
# level_3    1743
# level_1     140
# level_5      43
# level_2       4
# level_0       1
# Name: Education_level, dtype: int64

# %%
df_train_prep1['age when graduated'] = df_train_prep1['year_graduated'] - df_train_prep1['age']
df_train_prep1['age when graduated2'] = np.where(df_train_prep1['Education_level'].isin(['level_4','level_3']),df_train_prep1['Education_level'].isin(['level_4','level_3'])*df_train_prep1['age when graduated'],0)

# %%
df_test_prep1['age when graduated'] = df_test_prep1['year_graduated'] - df_test_prep1['age']
df_test_prep1['age when graduated2'] = np.where(df_test_prep1['Education_level'].isin(['level_4','level_3']),df_test_prep1['Education_level'].isin(['level_4','level_3'])*df_test_prep1['age when graduated'],0)

# %%
pd.crosstab(pd.qcut(df_train_prep1['age when graduated2'],4),df_train_prep1['Best Performance'],normalize = 0).plot(kind = 'bar')

# %% [markdown]
# age per dependencies

# %%
df_train_prep1['age per dependencies'] = (2020-df_train_prep1['age'])/(df_train_prep1['number_of_dependences']+1)
df_test_prep1['age per dependencies'] = (2020-df_test_prep1['age'])/(df_test_prep1['number_of_dependences']+1)

# %%
pd.crosstab(pd.qcut(df_train_prep1['age per dependencies'],4),df_train_prep1['Best Performance'],normalize = 0)
# Out:
# Best Performance             0         1
# age per dependencies
# (6.749, 13.667]       0.864865  0.135135
# (13.667, 16.5]        0.857813  0.142187
# (16.5, 30.0]          0.844858  0.155142
# (30.0, 54.0]          0.845268  0.154732

# %% [markdown]
# age married male

# %%
df_train_prep1['marital_status_maried(Y/N)'].value_counts()
# Out:
# Y    9501
# N    1652
# Name: marital_status_maried(Y/N), dtype: int64

# %%
df_train_prep1['gender'].value_counts()
# Out:
# 2    8204
# 1    2949
# Name: gender, dtype: int64

# %%
pd.crosstab(df_train_prep1['marital_status_maried(Y/N)'],df_train_prep1['gender'])
# Out:
# gender                         1     2
# marital_status_maried(Y/N)
# N                            501  1151
# Y                           2448  7053

# %%
df_train_prep1['age married male'] = (2020-df_train_prep1['age'])*(df_train_prep1['marital_status_maried(Y/N)'] == 'Y')*(df_train_prep1['gender']==1)
df_test_prep1['age married male'] = (2020-df_test_prep1['age'])*(df_test_prep1['marital_status_maried(Y/N)'] == 'Y')*(df_test_prep1['gender']==1)

# %%
pd.crosstab(pd.qcut(df_train_prep1[df_train_prep1['age married male']!=0]['age married male'],4),df_train_prep1[df_train_prep1['age married male']!=0]['Best Performance'],normalize = 0)
# Out:
# Best Performance         0         1
# age married male
# (24.999, 32.0]    0.828283  0.171717
# (32.0, 34.0]      0.850082  0.149918
# (34.0, 37.0]      0.843177  0.156823
# (37.0, 57.0]      0.847670  0.152330

# %%
pd.crosstab(pd.qcut(df_train_prep1[df_train_prep1['age married male']!=0]['age married male'],4),df_train_prep1[df_train_prep1['age married male']!=0]['Best Performance'],normalize = 0).plot(kind = 'bar')

# %%
df_train_prep1['age married male']
# Out:
# 0         0
# 1         0
# 2        50
# 3         0
# 4         0
#          ..
# 11148     0
# 11149    32
# 11150     0
# 11151    33
# 11152     0
# Name: age married male, Length: 11153, dtype: int64

# %%
df_train_prep1['papa muda'] = np.where((df_train_prep1['age married male']>=24.9)&(df_train_prep1['age married male']<=32),df_train_prep1['age married male'],0)
df_test_prep1['papa muda'] = np.where((df_test_prep1['age married male']>=24.9)&(df_test_prep1['age married male']<=32),df_test_prep1['age married male'],0)

# %% [markdown]
# age per dependencies papa muda

# %%
df_train_prep1['papa muda per tanggungan'] = df_train_prep1['papa muda']/(df_train_prep1['number_of_dependences']+1)
df_test_prep1['papa muda per tanggungan'] = df_test_prep1['papa muda']/(df_test_prep1['number_of_dependences']+1)

# %%
pd.crosstab(pd.qcut(df_train_prep1[df_train_prep1['papa muda per tanggungan']!=0]['papa muda per tanggungan'],4),df_train_prep1[df_train_prep1['papa muda per tanggungan']!=0]['Best Performance'],normalize = 0).plot(kind = 'bar')

# %% [markdown]
# for one hot

# %%
df_train_prep1['job_level_oh'] = df_train_prep1['job_level'] 
df_train_prep1['person_level_oh'] = df_train_prep1['person_level']

df_test_prep1['job_level_oh'] = df_test_prep1['job_level'] 
df_test_prep1['person_level_oh'] = df_test_prep1['person_level']

# %% [markdown]
# FE SKLEARN

# %%
df_train
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 0          JG04                           1.352775         PG03
# 1          JG04                           1.292285         PG03
# 2          JG05                           2.565151         PG06
# 3          JG05                           2.828427         PG06
# 4          JG05                           2.828427         PG06
# ...         ...                                ...          ...
# 11148      JG04                           1.256981         PG03
# 11149      JG04                           1.385641         PG03
# 11150      JG04                           1.256981         PG03
# 11151      JG04                           1.118034         PG03
# 11152      JG04                           2.828427         PG04
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                                  1.352775                        1.732051
# 1                                  1.292285                        1.039230
# 2                                  2.308679                        1.780449
# 3                                  1.000000                        1.385641
# 4                                  2.828427                        0.707107
# ...                                     ...                             ...
# 11148                              1.256981                        1.224745
# 11149                              1.385641                        1.802776
# 11150                              1.256981                        1.385641
# 11151                              1.118034                        0.000000
# 11152                              2.121320                        1.473092
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 0         RM_type_A       2  1985                          Y
# 1         RM_type_A       2  1989                          Y
# 2         RM_type_C       1  1970                          Y
# 3         RM_type_A       2  1967                          Y
# 4         RM_type_A       2  1965                          Y
# ...             ...     ...   ...                        ...
# 11148     RM_type_A       2  1986                          Y
# 11149     RM_type_B       1  1988                          Y
# 11150     RM_type_B       2  1991                          Y
# 11151     RM_type_A       1  1987                          Y
# 11152     RM_type_B       2  1980                          Y
#
#        number_of_dependences Education_level   GPA  year_graduated  \
# 0                          1         level_0  2.86            2011
# 1                          0         level_1  7.28            2007
# 2                          1         level_1  0.00            1989
# 3                          2         level_1  0.00            1987
# 4                          3         level_1  7.20            1985
# ...                      ...             ...   ...             ...
# 11148                      1         level_5  3.33            2016
# 11149                      2         level_5  3.00            2015
# 11150                      0         level_5  3.48            2017
# 11151                      1         level_5  3.53            2012
# 11152                      2         level_5  3.14            2009
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 0                               4                2             3
# 1                               4                4             3
# 2                              28               10             9
# 3                              29               11             6
# 4                              30                9             8
# ...                           ...              ...           ...
# 11148                           4                3             3
# 11149                           3                1             2
# 11150                           2                1             2
# 11151                           5                5             4
# 11152                          14                5             7
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                            2             3            0               46.37
# 1                            0             0            1               47.68
# 2                            6             2            1               40.73
# 3                            0             4           10               47.42
# 4                            2             3            0               47.18
# ...                        ...           ...          ...                 ...
# 11148                        0             4            1               50.87
# 11149                        0             6            0               79.91
# 11150                        0             4            0               78.38
# 11151                        0             4            1               85.94
# 11152                        0             2            0               79.99
#
#        Achievement_above_100%_during3quartal  Best Performance
# 0                                        0.0                 0
# 1                                        0.0                 0
# 2                                        0.0                 0
# 3                                        0.0                 1
# 4                                        0.0                 0
# ...                                      ...               ...
# 11148                                    0.0                 0
# 11149                                    0.0                 0
# 11150                                    0.0                 0
# 11151                                    1.0                 0
# 11152                                    1.0                 0
#
# [11153 rows x 22 columns]

# %%
df_train_prep1.columns
# Out:
# Index(['job_level', 'job_duration_in_current_job_level', 'person_level',
#        'job_duration_in_current_person_level',
#        'job_duration_in_current_branch', 'Employee_type', 'gender', 'age',
#        'marital_status_maried(Y/N)', 'number_of_dependences',
#        'Education_level', 'GPA', 'year_graduated',
#        'job_duration_from_training', 'branch_rotation', 'job_rotation',
#        'assign_of_otherposition', 'annual leave', 'sick_leaves',
#        'Last_achievement_%', 'Achievement_above_100%_during3quartal',
#        'Best Performance', 'total leave', 'age2', 'age3', 'year_graduated2',
#        'total_rotation', 'in study', 'person level up', 'job_level_oh',
#        'person_level_oh', 'sick_vs_leaves', 'age when graduated',
#        'age when graduated2'],
#       dtype='object')

# %%
object_var
# Out:
# Index(['job_level', 'person_level', 'Employee_type',
#        'marital_status_maried(Y/N)', 'Education_level'],
#       dtype='object')

# %%
numeric_var
# Out:
# ['job_duration_in_current_job_level',
#  'job_duration_in_current_person_level',
#  'job_duration_in_current_branch',
#  'age',
#  'number_of_dependences',
#  'GPA',
#  'branch_rotation',
#  'job_rotation',
#  'assign_of_otherposition',
#  'annual leave',
#  'sick_leaves',
#  'Last_achievement_%',
#  'Achievement_above_100%_during3quartal',
#  'year_graduated',
#  'total leave',
#  'total_rotation',
#  'age when graduated',
#  'age when graduated2']

# %%
df_train_prep1
# Out:
#       job_level  job_duration_in_current_job_level person_level  \
# 0          JG04                           1.352775         PG03
# 1          JG04                           1.292285         PG03
# 2          JG05                           2.565151         PG06
# 3          JG05                           2.828427         PG06
# 4          JG05                           2.828427         PG06
# ...         ...                                ...          ...
# 11148      JG04                           1.256981         PG03
# 11149      JG04                           1.385641         PG03
# 11150      JG04                           1.256981         PG03
# 11151      JG04                           1.118034         PG03
# 11152      JG04                           2.828427         PG04
#
#        job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                                  1.352775                        1.732051
# 1                                  1.292285                        1.039230
# 2                                  2.308679                        1.780449
# 3                                  1.000000                        1.385641
# 4                                  2.828427                        0.707107
# ...                                     ...                             ...
# 11148                              1.256981                        1.224745
# 11149                              1.385641                        1.802776
# 11150                              1.256981                        1.385641
# 11151                              1.118034                        0.000000
# 11152                              2.121320                        1.473092
#
#       Employee_type  gender   age marital_status_maried(Y/N)  \
# 0         RM_type_A       2  1985                          Y
# 1         RM_type_A       2  1989                          Y
# 2         RM_type_C       1  1970                          Y
# 3         RM_type_A       2  1967                          Y
# 4         RM_type_A       2  1965                          Y
# ...             ...     ...   ...                        ...
# 11148     RM_type_A       2  1986                          Y
# 11149     RM_type_B       1  1988                          Y
# 11150     RM_type_B       2  1991                          Y
# 11151     RM_type_A       1  1987                          Y
# 11152     RM_type_B       2  1980                          Y
#
#        number_of_dependences Education_level   GPA  year_graduated  \
# 0                          1         level_0  0.00            2011
# 1                          0         level_1  0.00            2007
# 2                          1         level_1  0.00            1989
# 3                          2         level_1  0.00            1987
# 4                          3         level_1  0.00            1985
# ...                      ...             ...   ...             ...
# 11148                      1         level_5  3.33            2016
# 11149                      2         level_5  3.00            2015
# 11150                      0         level_5  3.48            2017
# 11151                      1         level_5  3.53            2012
# 11152                      2         level_5  3.14            2009
#
#        job_duration_from_training  branch_rotation  job_rotation  \
# 0                               4                2             3
# 1                               4                4             3
# 2                              28               10             9
# 3                              29               11             6
# 4                              30                9             8
# ...                           ...              ...           ...
# 11148                           4                3             3
# 11149                           3                1             2
# 11150                           2                1             2
# 11151                           5                5             4
# 11152                          14                5             7
#
#        assign_of_otherposition  annual leave  sick_leaves  Last_achievement_%  \
# 0                            2             3            0               46.37
# 1                            0             0            1               47.68
# 2                            6             2            1               40.73
# 3                            0             4           10               47.42
# 4                            2             3            0               47.18
# ...                        ...           ...          ...                 ...
# 11148                        0             4            1               50.87
# 11149                        0             6            0               79.91
# 11150                        0             4            0               78.38
# 11151                        0             4            1               85.94
# 11152                        0             2            0               79.99
#
#        Achievement_above_100%_during3quartal  Best Performance  total leave  \
# 0                                        0.0                 0            3
# 1                                        0.0                 0            1
# 2                                        0.0                 0            3
# 3                                        0.0                 1           14
# 4                                        0.0                 0            3
# ...                                      ...               ...          ...
# 11148                                    0.0                 0            5
# 11149                                    0.0                 0            6
# 11150                                    0.0                 0            4
# 11151                                    1.0                 0            5
# 11152                                    1.0                 0            2
#
#             age2  age3 year_graduated2  total_rotation in study  \
# 0          ambis     2             new               7   finish
# 1          ambis     2             new               7   finish
# 2      non-ambis     4             old              25   finish
# 3      non-ambis     4             old              17   finish
# 4      non-ambis     4             old              19   finish
# ...          ...   ...             ...             ...      ...
# 11148      ambis     2             new               6   finish
# 11149      ambis     2             new               3   finish
# 11150      ambis     2             new               3   finish
# 11151      ambis     2             new               9   finish
# 11152  non-ambis     3             new              12   finish
#
#       person level up job_level_oh person_level_oh sick_vs_leaves  \
# 0                stay         JG04            PG03          leave
# 1                stay         JG04            PG03           sick
# 2                  up         JG05            PG06          leave
# 3                  up         JG05            PG06           sick
# 4                stay         JG05            PG06          leave
# ...               ...          ...             ...            ...
# 11148            stay         JG04            PG03          leave
# 11149            stay         JG04            PG03          leave
# 11150            stay         JG04            PG03          leave
# 11151            stay         JG04            PG03          leave
# 11152              up         JG04            PG04          leave
#
#        age when graduated  age when graduated2
# 0                      26                    0
# 1                      18                    0
# 2                      19                    0
# 3                      20                    0
# 4                      20                    0
# ...                   ...                  ...
# 11148                  30                    0
# 11149                  27                    0
# 11150                  26                    0
# 11151                  25                    0
# 11152                  29                    0
#
# [11153 rows x 34 columns]

# %%
new_var_one_hot = ['age2','age3','year_graduated2','in study','person level up','sick_vs_leaves']

one_hot_var = [
    'job_level_oh', 
    'person_level_oh', 
    'Employee_type', 
    'Education_level',
#     'Employee_status',   
    'gender', 
    'marital_status_maried(Y/N)'] + new_var_one_hot

ordinal_val = [
    'job_level',
    'person_level',
    'Education_level'
#     'achievement_target_1', 
#     'achievement_target_2'
]

new_var_num = ['year_graduated','total leave','total_rotation',
               'age when graduated','age when graduated2','papa muda',
               'papa muda per tanggungan','age per dependencies']

numeric_var = [
    'job_duration_in_current_job_level',   
    'job_duration_in_current_person_level',
    'job_duration_in_current_branch', 
    'age', 
    'number_of_dependences',
    'GPA',   
    'branch_rotation', 
    'job_rotation', 
    'assign_of_otherposition',   
    'annual leave', 
    'sick_leaves',
    'Last_achievement_%', 
    'Achievement_above_100%_during3quartal'] + new_var_num

# %%
# ordinal_mapping = [
#     {'col':'job_level',
#     'mapping':{None:0,'JG04':1,'JG05':2,'JG03':3,'JG06':4}},
#     {'col':'person_level',
#     'mapping':{None:0,'PG01':1,'PG02':2,'PG03':3,'PG04':4, 'PG05':5, 'PG06':6, 'PG07':7, 'PG08':8}},
#     {'col':'Education_level',
#     'mapping':{None:0,'level_0':1,'level_1':2,'level_2':3, 'level_3':4, 'level_4':5, 'level_5':6}}    
#     ]

# ordinal_encoder = ce.OrdinalEncoder(cols = ['job_level','person_level','Education_level'],mapping = ordinal_mapping)

one_hot_encoder_pipeline = Pipeline([
                                    ('one hot encoder',OneHotEncoder(handle_unknown = 'ignore'))
])

# numerical_pipeline = SimpleImputer(strategy = 'constant',fill_value = 0)

numerical_pipeline = Pipeline([
                                ('imputer',SimpleImputer(strategy = 'constant',fill_value = 0)),
                                ('bin',KBinsDiscretizer(encode = 'onehot',strategy = 'kmeans',n_bins=5))
])

transformer = ColumnTransformer([
    ('one hot encoder',one_hot_encoder_pipeline,one_hot_var),
#     ('ordinal encoder',ordinal_encoder,ordinal_val),
    ('numerical_pipeline',numerical_pipeline,numeric_var)
])

# %%
# ?KBinsDiscretizer

# %% [markdown]
# # Data Splitting

# %%
var_x = numeric_var + one_hot_var #+ ordinal_val

X = df_train_prep1[var_x]
X_sub = df_test_prep1[var_x]
y = df_train_prep1['Best Performance']

# %%
# seed = 1995
seed = 70621

X_trainval, X_test, y_trainval, y_test = train_test_split(X,y, stratify = y, test_size = 1500, random_state = seed)
X_train, X_val, y_train, y_val = train_test_split(X_trainval,y_trainval, stratify = y_trainval, test_size = 1500, random_state = seed)

# %% [markdown]
# > # Model (Benchmark)

# %%
# ?XGBClassifier

# %%
rates = 0.2

model = XGBClassifier(
    learning_rate = rates,
    n_estimators = 100,
    max_depth = 5,
    min_child_weight = 6,
    gamma= 30,
    subsample = 0.7,
    colsample_bynode = 0.4,
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    random_state = 20)


# model = CalibratedClassifierCV(model)

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('clf',model)
])

# %%
estimator.fit(X_train, y_train)
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('one hot encoder',
#                                                   Pipeline(steps=[('one hot '
#                                                                    'encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['job_level_oh',
#                                                    'person_level_oh',
#                                                    'Employee_type',
#                                                    'Education_level', 'gender',
#                                                    'marital_status_maried(Y/N)',
#                                                    'age2', 'age3',
#                                                    'year_graduated2',
#                                                    'in study',
#                                                    'person level up',
#                                                    'sick_vs_leaves']),
#                                                  ('numerical...
#                                colsample_bytree=1, gamma=30, gpu_id=-1,
#                                importance_type='gain',
#                                interaction_constraints='', learning_rate=0.2,
#                                max_delta_step=0, max_depth=5,
#                                min_child_weight=6, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=-1, num_parallel_tree=1, random_state=20,
#                                reg_alpha=0.005, reg_lambda=1,
#                                scale_pos_weight=1, subsample=0.7,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %%
y_prob_train = estimator.predict_proba(X_train)[:,1]
y_pred_train = np.where(y_prob_train > 0.13, 1, 0)

print('auc',roc_auc_score(y_train,y_prob_train),'\n')
print('classification report \n', classification_report(y_train,y_pred_train))
# Out:
# auc 0.5554003851876191
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      6956
#            1       0.15      1.00      0.26      1197
#
#     accuracy                           0.15      8153
#    macro avg       0.07      0.50      0.13      8153
# weighted avg       0.02      0.15      0.04      8153
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_prob_val = estimator.predict_proba(X_val)[:,1]
y_pred_val = np.where(y_prob_val > 0.13, 1, 0)

print('auc',roc_auc_score(y_val,y_prob_val),'\n')
print('classification report \n', classification_report(y_val,y_pred_val))
# Out:
# auc 0.5436079545454545
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
estimator.fit(X_trainval, y_trainval)
y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# auc 0.5751065340909092
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Prediction

# %%
estimator.fit(X,y)
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('one hot encoder',
#                                                   Pipeline(steps=[('one hot '
#                                                                    'encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['job_level_oh',
#                                                    'person_level_oh',
#                                                    'Employee_type',
#                                                    'Education_level', 'gender',
#                                                    'marital_status_maried(Y/N)',
#                                                    'age2', 'age3',
#                                                    'year_graduated2',
#                                                    'in study',
#                                                    'person level up',
#                                                    'sick_vs_leaves']),
#                                                  ('numerical...
#                                colsample_bytree=1, gamma=30, gpu_id=-1,
#                                importance_type='gain',
#                                interaction_constraints='', learning_rate=0.2,
#                                max_delta_step=0, max_depth=5,
#                                min_child_weight=6, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=-1, num_parallel_tree=1, random_state=20,
#                                reg_alpha=0.005, reg_lambda=1,
#                                scale_pos_weight=1, subsample=0.7,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %%
y_pred_sub = estimator.predict_proba(X_sub)[:,1]
df_test['Best Performance'] = y_pred_sub
df_submission = df_test[['Best Performance']]

# %%
df_submission.reset_index().to_csv('submission v1 base.csv',index = False)

# %% [markdown]
# # Model Selection Manual

# %%
rates = 0.2

model = LogisticRegression(solver = 'newton-cg')

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('clf',model)
])

# %%
estimator.fit(X_train, y_train)
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('one hot encoder',
#                                                   Pipeline(steps=[('one hot '
#                                                                    'encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['job_level_oh',
#                                                    'person_level_oh',
#                                                    'Employee_type',
#                                                    'Education_level', 'gender',
#                                                    'marital_status_maried(Y/N)',
#                                                    'age2', 'age3',
#                                                    'year_graduated2',
#                                                    'in study',
#                                                    'person level up',
#                                                    'sick_vs_leaves']),
#                                                  ('numerical...
#                                                    'number_of_dependences',
#                                                    'GPA', 'branch_rotation',
#                                                    'job_rotation',
#                                                    'assign_of_otherposition',
#                                                    'annual leave',
#                                                    'sick_leaves',
#                                                    'Last_achievement_%',
#                                                    'Achievement_above_100%_during3quartal',
#                                                    'year_graduated',
#                                                    'total leave',
#                                                    'total_rotation',
#                                                    'age when graduated',
#                                                    'age when graduated2',
#                                                    'papa muda',
#                                                    'papa muda per tanggungan',
#                                                    'age per dependencies'])])),
#                 ('clf', LogisticRegression(solver='newton-cg'))])

# %%
y_prob_train = estimator.predict_proba(X_train)[:,1]
y_pred_train = np.where(y_prob_train > 0.13, 1, 0)

print('auc',roc_auc_score(y_train,y_prob_train),'\n')
print('classification report \n', classification_report(y_train,y_pred_train))
# Out:
# auc 0.6209941544488017
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.90      0.47      0.62      6956
#            1       0.18      0.70      0.29      1197
#
#     accuracy                           0.50      8153
#    macro avg       0.54      0.58      0.45      8153
# weighted avg       0.80      0.50      0.57      8153

# %%
y_prob_val = estimator.predict_proba(X_val)[:,1]
y_pred_val = np.where(y_prob_val > 0.13, 1, 0)

print('auc',roc_auc_score(y_val,y_prob_val),'\n')
print('classification report \n', classification_report(y_val,y_pred_val))
# Out:
# auc 0.5545703125
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.88      0.45      0.59      1280
#            1       0.17      0.64      0.26       220
#
#     accuracy                           0.47      1500
#    macro avg       0.52      0.54      0.43      1500
# weighted avg       0.77      0.47      0.54      1500

# %%
y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5917933238636364
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.90      0.46      0.61      1280
#            1       0.18      0.70      0.29       220
#
#     accuracy                           0.49      1500
#    macro avg       0.54      0.58      0.45      1500
# weighted avg       0.79      0.49      0.56      1500

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.svm import SVC

# %%
model_xgb = XGBClassifier(
    learning_rate = 0.05,
    n_estimators = 1000,
    max_depth = 5,
    min_child_weight = 4,
    gamma= 30,
    subsample = 0.7,
    colsample_bynode = 0.4,
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    seed=27)

# model_xgb = CalibratedClassifierCV(model)

model_logreg = LogisticRegression(solver = 'newton-cg')
model_knn = KNeighborsClassifier()
model_dtc = DecisionTreeClassifier()
model_rf = RandomForestClassifier()
# model_svc = SVC(kernel = 'rbf')

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('clf',model)
])

skfold = StratifiedKFold(n_splits = 5)

hyperparam_space = {
    'clf':[model_xgb, model_logreg, model_knn, model_dtc, model_rf]
}

grid_search_model = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search_model.fit(X_trainval, y_trainval)
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/...
#                                                monotone_constraints=None,
#                                                n_estimators=1000, n_jobs=-1,
#                                                num_parallel_tree=None,
#                                                random_state=None,
#                                                reg_alpha=0.005, reg_lambda=None,
#                                                scale_pos_weight=None, seed=27,
#                                                subsample=0.7, tree_method=None,
#                                                validate_parameters=None,
#                                                verbosity=None),
#                                  LogisticRegression(solver='newton-cg'),
#                                  KNeighborsClassifier(),
#                                  DecisionTreeClassifier(),
#                                  RandomForestClassifier()]},
#              scoring='roc_auc')

# %%
print(grid_search_model.best_params_)
print(grid_search_model.best_score_)
# Out:
# {'clf': LogisticRegression(solver='newton-cg')}
# 0.5627476379565657

# %%
pd.DataFrame(grid_search_model.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      12.130388      0.129329         0.039871        0.005501
# 1       2.962251      0.110984         0.041644        0.006721
# 2       0.775165      0.158810         2.521174        0.489732
# 3       1.507274      0.088904         0.045067        0.012015
# 4       7.580913      0.273989         0.069686        0.005003
#
#                                            param_clf  \
# 0  XGBClassifier(base_score=None, booster=None, c...
# 1             LogisticRegression(solver='newton-cg')
# 2                             KNeighborsClassifier()
# 3                           DecisionTreeClassifier()
# 4                           RandomForestClassifier()
#
#                                               params  split0_test_score  \
# 0  {'clf': XGBClassifier(base_score=None, booster...           0.539521
# 1    {'clf': LogisticRegression(solver='newton-cg')}           0.551582
# 2                    {'clf': KNeighborsClassifier()}           0.499464
# 3                  {'clf': DecisionTreeClassifier()}           0.519032
# 4                  {'clf': RandomForestClassifier()}           0.538447
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.556744           0.566059           0.553818           0.545408
# 1           0.548659           0.575032           0.571703           0.566762
# 2           0.490876           0.527054           0.524145           0.512513
# 3           0.519322           0.539344           0.497887           0.510070
# 4           0.519497           0.576187           0.536243           0.551936
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.552310        0.009189                2
# 1         0.562748        0.010681                1
# 2         0.510811        0.013933                5
# 3         0.517131        0.013580                4
# 4         0.544462        0.018918                3

# %% [markdown]
# # Hyperparameter Tuning Logistic

# %%
one_hot_encoder_pipeline = Pipeline([
                                    ('one hot encoder',OneHotEncoder(handle_unknown = 'ignore'))
])

# numerical_pipeline = SimpleImputer(strategy = 'constant',fill_value = 0)

numerical_pipeline = Pipeline([
                                ('imputer',SimpleImputer(strategy = 'constant',fill_value = 0)),
                                ('bin',KBinsDiscretizer(encode = 'onehot',strategy = 'uniform'))
])

transformer = ColumnTransformer([
    ('one hot encoder',one_hot_encoder_pipeline,one_hot_var),
#     ('ordinal encoder',ordinal_encoder,ordinal_val),
    ('numerical_pipeline',numerical_pipeline,numeric_var)
])

# %%
# ?SelectFromModel

# %%
model = LogisticRegression(solver = 'newton-cg')

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

skfold = StratifiedKFold(n_splits = 4)

hyperparam_space = [{
    'preprocess__numerical_pipeline__bin__n_bins':[3,4,5,6],
    'preprocess__numerical_pipeline__bin__encode':['ordinal','onehot'],
    'preprocess__numerical_pipeline__bin__strategy':['uniform','quantile','kmeans'],
    'select__threshold':['0.5*median','0.75*median','median','1.25*median','1.5*median'],
    'clf__C':[0.001,0.01,0.1,1,10,100,1000]},
    {'preprocess__numerical_pipeline__bin__n_bins':[3,4,5,6],
    'preprocess__numerical_pipeline__bin__encode':['ordinal','onehot'],
    'preprocess__numerical_pipeline__bin__strategy':['uniform','quantile','kmeans'],
    'select':[None],
    'clf__C':[0.001,0.01,0.1,1,10,100,1000]}
]

grid_search_simple = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search_simple.fit(X_trainval, y_trainval)
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/...
#                           'select__threshold': ['0.5*median', '0.75*median',
#                                                 'median', '1.25*median',
#                                                 '1.5*median']},
#                          {'clf__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                           'preprocess__numerical_pipeline__bin__encode': ['ordinal',
#                                                                           'onehot'],
#                           'preprocess__numerical_pipeline__bin__n_bins': [3, 4,
#                                                                           5,
#                                                                           6],
#                           'preprocess__numerical_pipeline__bin__strategy': ['uniform',
#                                                                             'quantile',
#                                                                             'kmeans'],
#                           'select': [None]}],
#              scoring='roc_auc')

# %%
grid_search_simple.best_params_
# Out:
# {'clf__C': 0.01,
#  'preprocess__numerical_pipeline__bin__encode': 'onehot',
#  'preprocess__numerical_pipeline__bin__n_bins': 6,
#  'preprocess__numerical_pipeline__bin__strategy': 'kmeans',
#  'select__threshold': '0.75*median'}

# %%
grid_search_simple.best_score_
# Out:
# 0.5666229925520531

# %%
estimator = grid_search_simple.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# auc 0.58740234375
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.35      0.50      1280
#            1       0.16      0.75      0.27       220
#
#     accuracy                           0.41      1500
#    macro avg       0.53      0.55      0.39      1500
# weighted avg       0.78      0.41      0.47      1500

# %%
y_prob_trainval = estimator.predict_proba(X_trainval)[:,1]
y_pred_trainval = np.where(y_prob_trainval > 0.13, 1, 0)

print('auc',roc_auc_score(y_trainval,y_prob_trainval),'\n')
print('classification report \n', classification_report(y_trainval,y_pred_trainval))
# Out:
# auc 0.5981239137058744
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.36      0.52      8236
#            1       0.17      0.75      0.27      1417
#
#     accuracy                           0.42      9653
#    macro avg       0.53      0.56      0.40      9653
# weighted avg       0.79      0.42      0.48      9653

# %% [markdown]
# prediction

# %%
# estimator = grid_search_simple.best_estimator_

# %%
estimator.fit(X,y)
# Out:
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:189: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   centers = km.fit(column[:, None]).cluster_centers_[:, 0]
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:202: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 12 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('one hot encoder',
#                                                   Pipeline(steps=[('one hot '
#                                                                    'encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['job_level_oh',
#                                                    'person_level_oh',
#                                                    'Employee_type',
#                                                    'Education_level', 'gender',
#                                                    'marital_status_maried(Y/N)',
#                                                    'age2', 'age3',
#                                                    'year_graduated2',
#                                                    'in study',
#                                                    'person level up',
#                                                    'sick_vs_leaves']),
#                                                  ('numerical...
#                                                    'sick_leaves',
#                                                    'Last_achievement_%',
#                                                    'Achievement_above_100%_during3quartal',
#                                                    'year_graduated',
#                                                    'total leave',
#                                                    'total_rotation',
#                                                    'age when graduated',
#                                                    'age when graduated2',
#                                                    'papa muda',
#                                                    'papa muda per '
#                                                    'tanggungan'])])),
#                 ('select',
#                  SelectFromModel(estimator=LogisticRegression(solver='newton-cg'),
#                                  threshold='1.5*median')),
#                 ('clf', LogisticRegression(C=0.1, solver='newton-cg'))])

# %%
y_pred_sub = estimator.predict_proba(X_sub)[:,1]
df_test['Best Performance'] = y_pred_sub
df_submission = df_test[['Best Performance']]

# %%
df_submission.reset_index().to_csv('submission logreg2.csv',index = False)

# %% [markdown]
# # Hyperparameter Tuning (2nd Scenario)

# %% [markdown]
# 1

# %%
rates = 0.2

# %%
model = XGBClassifier(
    learning_rate = rates,
    n_estimators = 100,
    max_depth = 5,
    min_child_weight = 6,
    gamma= 30,
    subsample = 0.7,
    colsample_bynode = 0.4,
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    random_state = 20)

# model = CalibratedClassifierCV(model)

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

skfold = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 200)

hyperparam_space = {
    'clf__n_estimators':[60,80,100,120,150]
}

grid_search = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search.fit(X_trainval, y_trainval)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=200, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/N)...
#                                                       max_delta_step=None,
#                                                       max_depth=5,
#                                                       min_child_weight=6,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=100,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=20,
#                                                       reg_alpha=0.005,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=0.7,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1,
#              param_grid={'clf__n_estimators': [60, 80, 100, 120, 150]},
#              scoring='roc_auc')

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'clf__n_estimators': 60}
# 0.5289576490699506

# %%
estimator = grid_search.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5456321022727273
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 2

# %%
model = XGBClassifier(
    learning_rate = rates,
    n_estimators = grid_search.best_params_['clf__n_estimators'],
    max_depth = 5,
    min_child_weight = 6,
    gamma= 30,
    subsample = 0.7,
    colsample_bynode = 0.4,
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    random_state = 20)

# model = CalibratedClassifierCV(model)

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# skfold = StratifiedKFold(n_splits = 4)

hyperparam_space = {
    'clf__max_depth':range(3,6),
    'clf__min_child_weight':range(1,10)
}

grid_search2 = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search2.fit(X_trainval, y_trainval)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=200, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/N)...
#                                                       min_child_weight=6,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=60,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=20,
#                                                       reg_alpha=0.005,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=0.7,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1,
#              param_grid={'clf__max_depth': range(3, 6),
#                          'clf__min_child_weight': range(1, 10)},
#              scoring='roc_auc')

# %%
print(grid_search2.best_params_)
print(grid_search2.best_score_)
# Out:
# {'clf__max_depth': 3, 'clf__min_child_weight': 1}
# 0.5289576490699506

# %%
estimator = grid_search2.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5456321022727273
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 3

# %%
model = XGBClassifier(
    learning_rate = rates,
    n_estimators = grid_search.best_params_['clf__n_estimators'],
    max_depth = grid_search2.best_params_['clf__max_depth'],
    min_child_weight = grid_search2.best_params_['clf__min_child_weight'],
    gamma= 30,
    subsample = 0.7,
    colsample_bynode = 0.4,
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    random_state = 20)

# model = CalibratedClassifierCV(model)

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# skfold = StratifiedKFold(n_splits = 4)

hyperparam_space = {
    'clf__gamma':[25,30,35,40],
    'clf__colsample_bynode':[i/10 for i in range(2,6)]
}

grid_search3 = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search3.fit(X_trainval, y_trainval)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=200, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/N)...
#                                                       min_child_weight=1,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=60,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=20,
#                                                       reg_alpha=0.005,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=0.7,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1,
#              param_grid={'clf__colsample_bynode': [0.2, 0.3, 0.4, 0.5],
#                          'clf__gamma': [25, 30, 35, 40]},
#              scoring='roc_auc')

# %%
print(grid_search3.best_params_)
print(grid_search3.best_score_)
# Out:
# {'clf__colsample_bynode': 0.4, 'clf__gamma': 25}
# 0.5414001689168495

# %%
estimator = grid_search3.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5456321022727273
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 4

# %%
model = XGBClassifier(
    learning_rate = rates,
    n_estimators = grid_search.best_params_['clf__n_estimators'],
    max_depth = grid_search2.best_params_['clf__max_depth'],
    min_child_weight = grid_search2.best_params_['clf__min_child_weight'],
    gamma= grid_search3.best_params_['clf__gamma'],
    subsample = 0.7,
    colsample_bynode = grid_search3.best_params_['clf__colsample_bynode'],
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    random_state = 20)

# model = CalibratedClassifierCV(model)

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# skfold = StratifiedKFold(n_splits = 4)

hyperparam_space = {
    'clf__subsample':[i/10.0 for i in range(6,8)]
}

grid_search4 = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search4.fit(X_trainval, y_trainval)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=200, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/N)...
#                                                       max_delta_step=None,
#                                                       max_depth=3,
#                                                       min_child_weight=1,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=60,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=20,
#                                                       reg_alpha=0.005,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=0.7,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1, param_grid={'clf__subsample': [0.6, 0.7]},
#              scoring='roc_auc')

# %%
print(grid_search4.best_params_)
print(grid_search4.best_score_)
# Out:
# {'clf__subsample': 0.7}
# 0.5414001689168495

# %%
estimator = grid_search4.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5456321022727273
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 5

# %%
model = XGBClassifier(
    learning_rate = rates,
    n_estimators = grid_search.best_params_['clf__n_estimators'],
    max_depth = grid_search2.best_params_['clf__max_depth'],
    min_child_weight = grid_search2.best_params_['clf__min_child_weight'],
    gamma= grid_search3.best_params_['clf__gamma'],
    subsample = grid_search4.best_params_['clf__subsample'],
    colsample_bynode = grid_search3.best_params_['clf__colsample_bynode'],
    reg_alpha= 0.005,
    objective= 'binary:logistic',
    n_jobs = -1,
    random_state = 20)

# model = CalibratedClassifierCV(model)

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# skfold = StratifiedKFold(n_splits = 4)

hyperparam_space = {
    'clf__reg_alpha':[0.0005, 0.005, 0.001, 0.05, 0.01, 0.5, 0.1, 10],
    'clf__reg_lambda':[None, 0.001, 0.01, 0.1, 1, 10]
}

grid_search5 = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search5.fit(X_trainval, y_trainval)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=200, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/N)...
#                                                       monotone_constraints=None,
#                                                       n_estimators=60,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=20,
#                                                       reg_alpha=0.005,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=0.7,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1,
#              param_grid={'clf__reg_alpha': [0.0005, 0.005, 0.001, 0.05, 0.01,
#                                             0.5, 0.1, 10],
#                          'clf__reg_lambda': [None, 0.001, 0.01, 0.1, 1, 10]},
#              scoring='roc_auc')

# %%
print(grid_search5.best_params_)
print(grid_search5.best_score_)
# Out:
# {'clf__reg_alpha': 0.0005, 'clf__reg_lambda': None}
# 0.5414001689168495

# %%
estimator = grid_search5.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5456321022727273
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 6

# %%
model = XGBClassifier(
    learning_rate = rates,
    n_estimators = grid_search.best_params_['clf__n_estimators'],
    max_depth = grid_search2.best_params_['clf__max_depth'],
    min_child_weight = grid_search2.best_params_['clf__min_child_weight'],
    gamma= grid_search3.best_params_['clf__gamma'],
    subsample = grid_search4.best_params_['clf__subsample'],
    colsample_bynode = grid_search3.best_params_['clf__colsample_bynode'],
    reg_alpha = grid_search5.best_params_['clf__reg_alpha'],
    reg_lambda = grid_search5.best_params_['clf__reg_lambda'],
    objective = 'binary:logistic',
    n_jobs = -1)

# model = CalibratedClassifierCV(model)

select = SelectFromModel(model, threshold="median")

estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# skfold = StratifiedKFold(n_splits = 4)

hyperparam_space = [
    {'clf__learning_rate':[rates],'clf__n_estimators':[grid_search.best_params_['clf__n_estimators']]},
    {'clf__learning_rate':[rates/2],'clf__n_estimators':[grid_search.best_params_['clf__n_estimators']*2]}#,
#     {'clf__learning_rate':[rates/4],'clf__n_estimators':[grid_search.best_params_['clf__n_estimators']*4]},
#     {'clf__learning_rate':[rates/8],'clf__n_estimators':[grid_search.best_params_['clf__n_estimators']*8]},
#     {'clf__learning_rate':[rates/16],'clf__n_estimators':[grid_search.best_params_['clf__n_estimators']*16]}
]

grid_search6 = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skfold, # evaluation method
    scoring = 'roc_auc', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search6.fit(X_trainval, y_trainval)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=200, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('one '
#                                                                          'hot '
#                                                                          'encoder',
#                                                                          Pipeline(steps=[('one '
#                                                                                           'hot '
#                                                                                           'encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['job_level_oh',
#                                                                           'person_level_oh',
#                                                                           'Employee_type',
#                                                                           'Education_level',
#                                                                           'gender',
#                                                                           'marital_status_maried(Y/N)...
#                                                       monotone_constraints=None,
#                                                       n_estimators=60,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=None,
#                                                       reg_alpha=0.0005,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=0.7,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1,
#              param_grid=[{'clf__learning_rate': [0.2],
#                           'clf__n_estimators': [60]},
#                          {'clf__learning_rate': [0.1],
#                           'clf__n_estimators': [120]}],
#              scoring='roc_auc')

# %%
print(grid_search6.best_params_)
print(grid_search6.best_score_)
# Out:
# {'clf__learning_rate': 0.2, 'clf__n_estimators': 60}
# 0.5289576490699506

# %%
estimator = grid_search6.best_estimator_
estimator.fit(X_trainval,y_trainval)

y_prob_test = estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5502823153409091
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = XGBClassifier(
    learning_rate = grid_search6.best_params_['clf__learning_rate'],
    n_estimators = grid_search6.best_params_['clf__n_estimators'],
    max_depth = grid_search2.best_params_['clf__max_depth'],
    min_child_weight = grid_search2.best_params_['clf__min_child_weight'],
    gamma= grid_search3.best_params_['clf__gamma'],
    subsample = grid_search4.best_params_['clf__subsample'],
    colsample_bynode = grid_search3.best_params_['clf__colsample_bynode'],
    reg_alpha = grid_search5.best_params_['clf__reg_alpha'],
    reg_lambda = grid_search5.best_params_['clf__reg_lambda'],
    objective = 'binary:logistic',
    n_jobs = -1)

select = SelectFromModel(model, threshold="median")

model = CalibratedClassifierCV(model)

final_estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# %%
final_estimator.fit(X_trainval,y_trainval)

y_prob_test = final_estimator.predict_proba(X_test)[:,1]
y_pred_test = np.where(y_prob_test > 0.13, 1, 0)

print('auc',roc_auc_score(y_test,y_prob_test),'\n')
print('classification report \n', classification_report(y_test,y_pred_test))
# Out:
# auc 0.5506498579545455
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1280
#            1       0.15      1.00      0.26       220
#
#     accuracy                           0.15      1500
#    macro avg       0.07      0.50      0.13      1500
# weighted avg       0.02      0.15      0.04      1500
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_prob_trainval = final_estimator.predict_proba(X_trainval)[:,1]
y_pred_trainval = np.where(y_prob_trainval > 0.13, 1, 0)

print('auc',roc_auc_score(y_trainval,y_prob_trainval),'\n')
print('classification report \n', classification_report(y_trainval,y_pred_trainval))
# Out:
# auc 0.5469466716342147
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      8236
#            1       0.15      1.00      0.26      1417
#
#     accuracy                           0.15      9653
#    macro avg       0.07      0.50      0.13      9653
# weighted avg       0.02      0.15      0.04      9653
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\muhyi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Predict

# %%
model = XGBClassifier(
    learning_rate = grid_search6.best_params_['clf__learning_rate'],
    n_estimators = grid_search6.best_params_['clf__n_estimators'],
    max_depth = grid_search2.best_params_['clf__max_depth'],
    min_child_weight = grid_search2.best_params_['clf__min_child_weight'],
    gamma= grid_search3.best_params_['clf__gamma'],
    subsample = grid_search4.best_params_['clf__subsample'],
    colsample_bynode = grid_search3.best_params_['clf__colsample_bynode'],
    reg_alpha = grid_search5.best_params_['clf__reg_alpha'],
    reg_lambda = grid_search5.best_params_['clf__reg_lambda'],
    objective = 'binary:logistic',
    n_jobs = -1)

select = SelectFromModel(model, threshold="median")

model = CalibratedClassifierCV(model)

final_estimator = Pipeline([
                      ('preprocess',transformer),
                      ('select',select),
                      ('clf',model)
])

# %%
# final_estimator = grid_search2.best_estimator_

# %%
final_estimator.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('one hot encoder',
#                                                   Pipeline(steps=[('one hot '
#                                                                    'encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['job_level_oh',
#                                                    'person_level_oh',
#                                                    'Employee_type',
#                                                    'Education_level', 'gender',
#                                                    'marital_status_maried(Y/N)',
#                                                    'age2', 'age3',
#                                                    'year_graduated2',
#                                                    'in study',
#                                                    'person level up']),
#                                                  ('numerical_pipeline',
#                                                   Simple...
#                                                                      importance_type='gain',
#                                                                      interaction_constraints=None,
#                                                                      learning_rate=0.1,
#                                                                      max_delta_step=None,
#                                                                      max_depth=4,
#                                                                      min_child_weight=1,
#                                                                      missing=nan,
#                                                                      monotone_constraints=None,
#                                                                      n_estimators=160,
#                                                                      n_jobs=-1,
#                                                                      num_parallel_tree=None,
#                                                                      random_state=None,
#                                                                      reg_alpha=0.0005,
#                                                                      reg_lambda=0.001,
#                                                                      scale_pos_weight=None,
#                                                                      subsample=0.7,
#                                                                      tree_method=None,
#                                                                      validate_parameters=None,
#                                                                      verbosity=None)))])

# %%
y_pred_sub = final_estimator.predict_proba(X_sub)[:,1]

# %%
df_test['Best Performance'] = y_pred_sub

# %%
df_submission = df_test[['Best Performance']]

# %%
df_submission.reset_index().to_csv('submission v1 - step by step.csv',index = False)
